# %%
import pandas as pd
import requests
import os
from nba_api.stats.static import players,teams


series=pd.read_csv('https://raw.githubusercontent.com/gabriel1200/nba_rapm/main/playoff_series.csv')
series=series[series.year>=2014]

frames=[]
for year in range(2014,2025):
    frame=pd.read_csv(str(year)+'.csv')
    frame2=pd.read_csv(str(year)+'_2.csv')
    joined_columns = set(frame2.columns) - set(frame.columns)
    joined_columns = list(joined_columns)
    joined_columns.append('PLAYER_ID')
    joined_columns.append('date')
    frame2 = frame2[joined_columns]
    frame=frame.merge(frame2,on=['PLAYER_ID','date'],how='left')
    frames.append(frame)
df=pd.concat(frames),
df.drop_duplicates(inplace=True)
print(len(df))
def get_dates():
    dates=[]
    for year in range(2014,2025):
    
        for team in teams.get_teams():
            team_id=team['id']
            path = '../team/'+str(year)+'ps/'+str(team_id)+'.csv'
            if os.path.exists(path):
                df=pd.read_csv(path)
    
                df=df[['PLAYER_ID','TEAM_ID','HTM','VTM','GAME_DATE']]
                df.rename(columns={'GAME_DATE':'date'},inplace=True)
                df.drop_duplicates(inplace=True)
                dates.append(df)
    return pd.concat(dates)
dates=get_dates()
df=df.merge(dates,how='left').reset_index(drop=True)
home=df[df.HTM==df.TEAM_ABBREVIATION].reset_index(drop=True)
home.drop(columns='HTM',inplace=True)

home.rename(columns={'VTM':'opp_team'},inplace=True)


home

away=df[df.VTM==df.TEAM_ABBREVIATION].reset_index(drop=True)
away.drop(columns='VTM',inplace=True)
away.rename(columns={'HTM':'opp_team'},inplace=True)

away

none=df[df.HTM.isna()].reset_index(drop=True)
#none.drop(columns=['VTM','HTM'],inplace=True)
df=pd.concat([home,away,none])


oppframe=df[['TEAM_ID','date','opp_team']]
oppframe.dropna(subset='opp_team',inplace=True)
oppframe.drop_duplicates(inplace=True)
df.drop(columns='opp_team',inplace=True)

#df=df.merge(oppframe)
df

df=df.merge(oppframe,on=['TEAM_ID','date'],how='left')
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 17
#      15 joined_columns = list(joined_columns)
#      16 joined_columns.append(['PLAYER_ID','GAME_DATE'])
# ---> 17 frame2 = frame2[joined_columns]
#      18 frame=frame.merge(frame2,on=['PLAYER_ID','GAME_DATE'],how='left')
#      19 frames.append(frame)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:6065, in Index._get_indexer_strict(self, key, axis_name)
#    6062     keyarr = com.asarray_tuplesafe(keyarr)
#    6064 if self._index_as_unique:
# -> 6065     indexer = self.get_indexer_for(keyarr)
#    6066     keyarr = self.reindex(keyarr)[0]
#    6067 else:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:6052, in Index.get_indexer_for(self, target)
#    6034 """
#    6035 Guaranteed return of an indexer even when non-unique.
#    6036
#    (...)
#    6049 array([0, 2])
#    6050 """
#    6051 if self._index_as_unique:
# -> 6052     return self.get_indexer(target)
#    6053 indexer, _ = self.get_indexer_non_unique(target)
#    6054 return indexer
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3973, in Index.get_indexer(self, target, method, limit, tolerance)
#    3968     target = target.astype(dtype, copy=False)
#    3969     return this._get_indexer(
#    3970         target, method=method, limit=limit, tolerance=tolerance
#    3971     )
# -> 3973 return self._get_indexer(target, method, limit, tolerance)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:4000, in Index._get_indexer(self, target, method, limit, tolerance)
#    3997     else:
#    3998         tgt_values = target._get_engine_target()
# -> 4000     indexer = self._engine.get_indexer(tgt_values)
#    4002 return ensure_platform_int(indexer)
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:308, in pandas._libs.index.IndexEngine.get_indexer()
#
# File pandas/_libs/hashtable_class_helper.pxi:5794, in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'list'

# %%
none2=df[df.opp_team.isna()]
df=df.dropna(subset='opp_team')
teammap=dict(zip(df['TEAM_ABBREVIATION'],df['TEAM_ID']))

df['opp_id']=df['opp_team'].map(teammap)
df.to_csv('playoff_data.csv',index=False)
# Out:
# /tmp/ipykernel_20418/2211292126.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['opp_id']=df['opp_team'].map(teammap)

# %%
df[df.TEAM_ABBREVIATION=='DET']
df['team']=df['TEAM_ABBREVIATION']
# Out:
# /tmp/ipykernel_20418/2916735606.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['team']=df['TEAM_ABBREVIATION']

# %%
df.sort_values(by='date',inplace=True)

df['series_key']=df['team']+'_'+df['opp_team']+'_'+df['year'].astype(str)
df
# Out:
# /tmp/ipykernel_20418/1847432245.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by='date',inplace=True)
# /tmp/ipykernel_20418/1847432245.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_key']=df['team']+'_'+df['opp_team']+'_'+df['year'].astype(str)
#        PLAYER_ID      PLAYER_NAME  NICKNAME     TEAM_ID TEAM_ABBREVIATION  \
# 0         101161     Amir Johnson      Amir  1610612761               TOR
# 113424      2419  Tayshaun Prince  Tayshaun  1610612763               MEM
# 113423      2581      Steve Blake     Steve  1610612744               GSW
# 113422      2581      Steve Blake     Steve  1610612744               GSW
# 113421      2581      Steve Blake     Steve  1610612744               GSW
# ...          ...              ...       ...         ...               ...
# 107618    201143       Al Horford        Al  1610612738               BOS
# 107619    201143       Al Horford        Al  1610612738               BOS
# 107620    201143       Al Horford        Al  1610612738               BOS
# 107622    201143       Al Horford        Al  1610612738               BOS
# 218331   1629023  P.J. Washington      P.J.  1610612742               DAL
#
#          AGE  GP  W  L  W_PCT  ...  FGA_LT_06  FGM_35_39  FGP_35_39  \
# 0       27.0   1  0  1    0.0  ...        NaN        NaN        NaN
# 113424  34.0   1  0  1    0.0  ...        1.0        NaN        NaN
# 113423  34.0   1  1  0    1.0  ...        2.0        NaN        NaN
# 113422  34.0   1  1  0    1.0  ...        3.0        NaN        NaN
# 113421  34.0   1  1  0    1.0  ...        2.0        NaN        NaN
# ...      ...  .. .. ..    ...  ...        ...        ...        ...
# 107618  38.0   1  1  0    1.0  ...        7.0        NaN        NaN
# 107619  38.0   1  1  0    1.0  ...        8.0        NaN        NaN
# 107620  38.0   1  1  0    1.0  ...       13.0        NaN        NaN
# 107622  38.0   1  1  0    1.0  ...       19.0        NaN        NaN
# 218331  25.0   1  0  1    0.0  ...       89.0        NaN        NaN
#
#         FGP_40_PLUS  HTM  VTM  opp_team      opp_id  team    series_key
# 0               NaN  NaN  NaN       BKN  1610612751   TOR  TOR_BKN_2014
# 113424          NaN  NaN  NaN       OKC  1610612760   MEM  MEM_OKC_2014
# 113423          NaN  NaN  NaN       LAC  1610612746   GSW  GSW_LAC_2014
# 113422          NaN  NaN  NaN       LAC  1610612746   GSW  GSW_LAC_2014
# 113421          NaN  NaN  NaN       LAC  1610612746   GSW  GSW_LAC_2014
# ...             ...  ...  ...       ...         ...   ...           ...
# 107618          NaN  NaN  NaN       DAL  1610612742   BOS  BOS_DAL_2024
# 107619          NaN  NaN  NaN       DAL  1610612742   BOS  BOS_DAL_2024
# 107620          NaN  NaN  NaN       DAL  1610612742   BOS  BOS_DAL_2024
# 107622          NaN  NaN  NaN       DAL  1610612742   BOS  BOS_DAL_2024
# 218331          NaN  NaN  NaN       BOS  1610612738   DAL  DAL_BOS_2024
#
# [238089 rows x 324 columns]

# %%
for key in df['series_key'].unique():
    series=df[df.series_key==key]
    series.to_csv('data/'+key+'.csv',index=False)

# %%
series=pd.read_csv('https://raw.githubusercontent.com/gabriel1200/nba_rapm/main/playoff_series.csv')
series.columns
# Out:
# Index(['PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'AGE', 'GP', 'W', 'L', 'W_PCT',
#        ...
#        'OPP_TS_PCT', 'rs_OPP_OFF_RATING', 'rs_OPP_DEF_RATING',
#        'rs_OPP_ROFF_RATING', 'rs_OPP_RDEF_RATING', 'year_avg_ts',
#        'rOPP_TS_PCT', 'rTS_PCT', 'ADJ_OFF_RATING', 'ADJ_DEF_RATING'],
#       dtype='object', length=137)

# %%
series['OPP_ID']

series=series[['PLAYER_ID','TEAM_ID','OPP_ID']]
series.to_csv('series_index.csv',index=False)
