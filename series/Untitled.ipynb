# %%
import pandas as pd
df=pd.read_csv('2014.csv')
df[df.PLAYER_ID==2544]
# Out:
#       PLAYER_ID   PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION   AGE  \
# 258        2544  LeBron James   LeBron  1610612748               MIA  29.0
# 331        2544  LeBron James   LeBron  1610612748               MIA  29.0
# 524        2544  LeBron James   LeBron  1610612748               MIA  29.0
# 791        2544  LeBron James   LeBron  1610612748               MIA  29.0
# 1309       2544  LeBron James   LeBron  1610612748               MIA  29.0
# 1356       2544  LeBron James   LeBron  1610612748               MIA  29.0
# 1404       2544  LeBron James   LeBron  1610612748               MIA  29.0
# 1452       2544  LeBron James   LeBron  1610612748               MIA  29.0
# 1493       2544  LeBron James   LeBron  1610612748               MIA  29.0
# 1529       2544  LeBron James   LeBron  1610612748               MIA  29.0
# 1549       2544  LeBron James   LeBron  1610612748               MIA  29.0
# ...

# %%
df=df[['VTM','HTM','GAME_DATE']]
df.drop_duplicates()
# Out:
#       VTM  HTM  GAME_DATE
# 0     CHA  MIA   20140420
# 76    CHA  MIA   20140423
# 143   MIA  CHA   20140426
# 226   MIA  CHA   20140428
# 304   BKN  MIA   20140506
# 378   BKN  MIA   20140508
# 449   MIA  BKN   20140510
# 517   MIA  BKN   20140512
# 587   BKN  MIA   20140514
# 654   MIA  IND   20140518
# 732   MIA  IND   20140520
# 799   IND  MIA   20140524
# 867   IND  MIA   20140526
# 936   MIA  IND   20140528
# 1011  IND  MIA   20140530
# 1087  MIA  SAS   20140605
# 1165  MIA  SAS   20140608
# 1235  SAS  MIA   20140610
# 1297  SAS  MIA   20140612
# 1368  MIA  SAS   20140615
