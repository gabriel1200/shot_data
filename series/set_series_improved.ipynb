# %%
import pandas as pd
import requests
import os
from nba_api.stats.static import teams
import io

def get_dates(start_year=2025, end_year=2026):
    dates = []
    print(f"DEBUG: Looking for data from {start_year} to {end_year-1}")
    
    for year in range(start_year, end_year):
        print(f"DEBUG: Processing year {year}")
        year_files_found = 0
        
        for team in teams.get_teams():
            team_id = team['id']
            team_name = team['full_name']
            path = f'../team/{year}ps/{team_id}.csv'
            
            if os.path.exists(path):
                year_files_found += 1
                print(f"DEBUG: Found file for {team_name} ({team_id}): {path}")
                
                try:
                    df = pd.read_csv(path)
                    print(f"DEBUG: File shape: {df.shape}, Columns: {list(df.columns)}")
                    
                    # Check if required columns exist
                    required_cols = {'PLAYER_ID', 'HTM', 'VTM', 'GAME_DATE', 'GAME_ID'}
                    if required_cols.issubset(df.columns):
                        df = df[['PLAYER_ID', 'HTM', 'VTM', 'GAME_DATE', 'GAME_ID']]
                        df['year'] = year
                        df.drop_duplicates(inplace=True)
                        print(f"DEBUG: Added {len(df)} unique games from {team_name}")
                        dates.append(df)
                    else:
                        missing_cols = required_cols - set(df.columns)
                        print(f"DEBUG: Missing columns in {team_name} file: {missing_cols}")
                        
                except Exception as e:
                    print(f"DEBUG: Error reading {path}: {e}")
            else:
                # Only print for first few teams to avoid spam
                if team_id <= 1610612739:  # First few team IDs
                    print(f"DEBUG: File not found for {team_name} ({team_id}): {path}")
        
        print(f"DEBUG: Year {year} - Found {year_files_found} team files")
    
    if dates:
        combined_df = pd.concat(dates).drop_duplicates(subset='GAME_ID')
        print(f"DEBUG: Total unique games found: {len(combined_df)}")
        print(f"DEBUG: Date range: {combined_df['GAME_DATE'].min()} to {combined_df['GAME_DATE'].max()}")
        return combined_df
    else:
        print("DEBUG: No valid data files found")
        return pd.DataFrame()

def fetch_game_csvs(dateframe, save_dir='game_data'):
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    all_game_data = []
    successful_fetches = 0
    failed_fetches = 0
    
    print(f"DEBUG: Attempting to fetch {len(dateframe)} games")
    
    for idx, (_, row) in enumerate(dateframe.iterrows()):
        year = int(row['year'])
        game_id = row['GAME_ID']
        url = f'https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/{year}/{game_id}.csv'
        
        # Print progress every 10 games
        if idx % 10 == 0:
            print(f"DEBUG: Processing game {idx+1}/{len(dateframe)}")
        
        print(f"DEBUG: Fetching {url}")
        
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            
            # Check if response is actually CSV data
            if len(response.text.strip()) == 0:
                print(f"DEBUG: Empty response for {game_id}")
                failed_fetches += 1
                continue
                
            df = pd.read_csv(io.StringIO(response.text))
            print(f"DEBUG: Successfully loaded CSV with {len(df)} rows, {len(df.columns)} columns")
            
            df['GAME_ID'] = game_id
            df['date'] = row['GAME_DATE']
            df['HTM'] = row['HTM']
            df['VTM'] = row['VTM']
            df['year'] = year
            all_game_data.append(df)
            successful_fetches += 1

            # Save raw CSV locally
            filename = os.path.join(save_dir, f'{year}_{game_id}.csv')
            with open(filename, 'w', encoding='utf-8') as f:
                f.write(response.text)
            print(f"DEBUG: Saved to {filename}")

        except requests.HTTPError as e:
            print(f'DEBUG: HTTP Error for {url}: {e} (Status: {e.response.status_code if hasattr(e, "response") else "Unknown"})')
            failed_fetches += 1
        except requests.Timeout:
            print(f'DEBUG: Timeout for {url}')
            failed_fetches += 1
        except Exception as e:
            print(f'DEBUG: Unexpected error for {game_id}: {type(e).__name__}: {e}')
            failed_fetches += 1
    
    print(f"DEBUG: Fetch summary - Success: {successful_fetches}, Failed: {failed_fetches}")
    
    if all_game_data:
        combined_df = pd.concat(all_game_data, ignore_index=True)
        print(f"DEBUG: Combined dataframe shape: {combined_df.shape}")
        return combined_df
    else:
        print("DEBUG: No game data successfully fetched")
        return pd.DataFrame()

def process_and_save_series_data(df, dateframe):
    print(f"DEBUG: Processing dataframe with {len(df)} rows")
    
    # Merge HTM, VTM, GAME_DATE, year from dateframe
    df.rename(columns={'GAME_DATE': 'date'}, inplace=True)
    if 'opp_team' in df.columns:
        df.drop(columns='opp_team',inplace=True)

    # Debug team abbreviations
    print(f"DEBUG: Unique team abbreviations in data: {sorted(df['TEAM_ABBREVIATION'].unique())}")
    print(f"DEBUG: Unique HTM values: {sorted(df['HTM'].dropna().unique())}")
    print(f"DEBUG: Unique VTM values: {sorted(df['VTM'].dropna().unique())}")

    # Home/away split using merged HTM/VTM
    home = df[df.HTM == df.TEAM_ABBREVIATION].copy()
    away = df[df.VTM == df.TEAM_ABBREVIATION].copy()
    none = df[df.HTM.isna()].copy().reset_index(drop=True)
    
    print(f"DEBUG: Home games: {len(home)}, Away games: {len(away)}, Games with no HTM: {len(none)}")
    
    home.drop(columns='HTM', inplace=True)
    home.rename(columns={'VTM': 'opp_team'}, inplace=True)

    away.drop(columns='VTM', inplace=True)
    away.rename(columns={'HTM': 'opp_team'}, inplace=True)

    home.drop_duplicates(inplace=True)
    away.drop_duplicates(inplace=True)
    
    frames = [home, away]
    if len(none) > 0:
        frames.append(none)
    df = pd.concat(frames, ignore_index=True)

    print(f"DEBUG: After home/away split: {len(df)} rows")

    # Map opp_team from date/team_id
    oppframe = df[['TEAM_ID', 'date', 'opp_team']].dropna(subset=['opp_team']).drop_duplicates()
    print(f"DEBUG: Opponent mapping frame: {len(oppframe)} rows")
    print(oppframe.head())
    
    df.drop(columns='opp_team', inplace=True)
    df = df.merge(oppframe, on=['TEAM_ID', 'date'], how='left')

    df['team'] = df['TEAM_ABBREVIATION']
    teammap = dict(zip(df['TEAM_ABBREVIATION'], df['TEAM_ID']))

    print(f"DEBUG: Team mapping created with {len(teammap)} teams")
    print('Printing Team Map')
    print(teammap)
    # Build current player index
    player_index = df[['PLAYER_NAME', 'PLAYER_ID', 'team', 'TEAM_ID', 'opp_team', 'year']].copy()
    player_index['opp_id'] = player_index['opp_team'].map(teammap)
    player_index.drop_duplicates(inplace=True)

    print(f"DEBUG: Player index created with {len(player_index)} unique entries")

    # Merge with existing index file if it exists
    index_path = 'series_index_players.csv'
    if os.path.exists(index_path):
        existing_index = pd.read_csv(index_path)
        print(f"DEBUG: Found existing player index with {len(existing_index)} rows")
        combined = pd.concat([existing_index, player_index], ignore_index=True)
        combined.drop_duplicates(
            subset=['PLAYER_ID', 'team', 'TEAM_ID', 'opp_team', 'year'], keep='last', inplace=True
        )
        combined.to_csv(index_path, index=False)
        print(f"DEBUG: Updated player index saved with {len(combined)} rows")
    else:
        player_index.to_csv(index_path, index=False)
        print(f"DEBUG: New player index saved with {len(player_index)} rows")

    # Continue data cleanup
    df = df.dropna(subset=['opp_team'])
    print(f"DEBUG: After dropping rows with no opponent: {len(df)} rows")
    print(f"DEBUG: Unique opponents: {sorted(df.opp_team.unique())}")

    df['opp_id'] = df['opp_team'].map(teammap)
    df.sort_values(by='date', inplace=True)
    df['series_key'] = df['team'] + '_' + df['opp_team'] + '_' + df['year'].astype(str)
    
    unique_series = df['series_key'].nunique()
    print(f"DEBUG: Created {unique_series} unique series")
    
    series_index = df[['series_key', 'team', 'opp_team', 'TEAM_ID','opp_id', 'year']]
    series_index.drop_duplicates(inplace=True)
    
    series_index_path = 'series_index.csv'
    if os.path.exists(series_index_path):
        existing_series_index = pd.read_csv(series_index_path)
        print(f"DEBUG: Found existing series index with {len(existing_series_index)} rows")
        combined_series_index = pd.concat([existing_series_index, series_index], ignore_index=True)
        combined_series_index.drop_duplicates(
            subset=['series_key', 'team', 'TEAM_ID', 'opp_team', 'opp_id', 'year'], keep='last', inplace=True
        )
        combined_series_index.to_csv(series_index_path, index=False)
        print(f"DEBUG: Updated series index saved with {len(combined_series_index)} rows")
    else:
        series_index.to_csv(series_index_path, index=False)
        print(f"DEBUG: New series index saved with {len(series_index)} rows")
    
    df.to_csv('playoff_data.csv', index=False)
    print(f"DEBUG: Main playoff data saved with {len(df)} rows")

    # Save series-specific dataframes
    series_dir = '../series/data'
    os.makedirs(series_dir, exist_ok=True)
    
    series_count = 0
    for key, group in df.groupby('series_key'):
        safe_key = key.replace('/', '-').replace('\\', '-')  # sanitize for filesystem
        filename = os.path.join(series_dir, f'{safe_key}.csv')
        group.to_csv(filename, index=False)
        series_count += 1
        if series_count <= 5:  # Only print first 5 to avoid spam
            print(f"DEBUG: Saved series {safe_key} with {len(group)} rows to {filename}")
    
    print(f"DEBUG: Saved {series_count} individual series files")
    return df

def check_directory_structure():
    """Check what years and team directories actually exist"""
    print("DEBUG: Checking directory structure...")
    
    base_path = '../team'
    if not os.path.exists(base_path):
        print(f"DEBUG: Base path {base_path} does not exist!")
        return
    
    # Check what year directories exist
    year_dirs = []
    for item in os.listdir(base_path):
        item_path = os.path.join(base_path, item)
        if os.path.isdir(item_path):
            year_dirs.append(item)
    
    print(f"DEBUG: Available year directories: {sorted(year_dirs)}")
    
    # Check each year directory
    for year_dir in sorted(year_dirs):
        year_path = os.path.join(base_path, year_dir)
        files = [f for f in os.listdir(year_path) if f.endswith('.csv')]

# === Enhanced Run Pipeline ===
def run_pipeline(start_year=2024, end_year=2025):
    print("="*50)
    print("STARTING NBA DATA PIPELINE DEBUG")
    print("="*50)
    
    # First check directory structure
    check_directory_structure()
    
    print(f"\nAttempting to process years {start_year} to {end_year-1}")
    
    dates = get_dates(start_year, end_year)
    if dates.empty:
        print(f'ERROR: No game date data found for {start_year}-{end_year - 1}.')
        print("This could be because:")
        print("1. The year directories don't exist")
        print("2. The CSV files don't exist in those directories")
        print("3. The CSV files exist but don't have the required columns")
        print("4. The path structure is different than expected")
        return None
    else:
        print(f"SUCCESS: Found game dates for {len(dates)} games")
        raw_df = fetch_game_csvs(dates)
        if raw_df.empty:
            print('ERROR: No game CSVs successfully fetched.')
            print("This could be because:")
            print("1. The GitHub repository structure is different for older years")
            print("2. The game IDs have a different format")
            print("3. Network connectivity issues")
            print("4. The files don't exist in the repository for those years")
            return None
        else:
            print(f"SUCCESS: Fetched {len(raw_df)} rows of game data")
            processed_df = process_and_save_series_data(raw_df, dates)
            print("PIPELINE COMPLETED SUCCESSFULLY")
            return processed_df

# Run with different years to test
if __name__ == "__main__":
    # Test with 2025 first (working)
    print("Testing 2025 (should work):")
    result_2025 = run_pipeline(2025, 2026)
    
    print("\n" + "="*80 + "\n")
    
    # Test with 2024 (not working)
    print("Testing 2024 (problematic):")
    result_2024 = run_pipeline(2024, 2025)
    
    print("\n" + "="*80 + "\n")
    
    # Test with 2023 (not working)
    print("Testing 2023 (problematic):")
    result_2023 = run_pipeline(2023, 2024)
# Out:
# Testing 2025 (should work):
# ==================================================
# STARTING NBA DATA PIPELINE DEBUG
# ==================================================
# DEBUG: Checking directory structure...
# DEBUG: Available year directories: ['1997', '1997ps', '1998', '1998ps', '1999', '1999ps', '2000', '2000ps', '2001', '2001ps', '2002', '2002ps', '2003', '2003ps', '2004', '2004ps', '2005', '2005ps', '2006', '2006ps', '2007', '2007ps', '2008', '2008ps', '2009', '2009ps', '2010', '2010ps', '2011', '2011ps', '2012', '2012ps', '2013', '2013ps', '2014', '2014ps', '2015', '2015ps', '2016', '2016ps', '2017', '2017ps', '2018', '2018ps', '2019', '2019ps', '2020', '2020ps', '2021', '2021ps', '2022', '2022ps', '2023', '2023ps', '2024', '2024ps', '2025', '2025ps']
# DEBUG: 1997 contains 59 CSV files
# DEBUG: Sample files in 1997: ['1610612741vs.csv', '1610612764vs.csv', '1610612751vs.csv']
# DEBUG: 1997ps contains 33 CSV files
# DEBUG: Sample files in 1997ps: ['1610612741vs.csv', '1610612764vs.csv', '1610612765.csv']
# DEBUG: 1998 contains 59 CSV files
# DEBUG: Sample files in 1998: ['1610612741vs.csv', '1610612764vs.csv', '1610612751vs.csv']
# DEBUG: 1998ps contains 33 CSV files
# DEBUG: Sample files in 1998ps: ['1610612741vs.csv', '1610612751vs.csv', '1610612759vs.csv']
# DEBUG: 1999 contains 59 CSV files
# DEBUG: Sample files in 1999: ['1610612741vs.csv', '1610612764vs.csv', '1610612751vs.csv']
# DEBUG: 1999ps contains 33 CSV files
# DEBUG: Sample files in 1999ps: ['1610612759vs.csv', '1610612765.csv', '1610612752.csv']
# DEBUG: 2000 contains 59 CSV files
# DEBUG: Sample files in 2000: ['1610612741vs.csv', '1610612764vs.csv', '1610612751vs.csv']
# DEBUG: 2000ps contains 33 CSV files
# DEBUG: Sample files in 2000ps: ['1610612759vs.csv', '1610612765.csv', '1610612752.csv']
# DEBUG: 2001 contains 59 CSV files
# DEBUG: Sample files in 2001: ['1610612741vs.csv', '1610612764vs.csv', '1610612751vs.csv']
# DEBUG: 2001ps contains 33 CSV files
# DEBUG: Sample files in 2001ps: ['1610612759vs.csv', '1610612752.csv', '1610612747vs.csv']
# DEBUG: 2002 contains 59 CSV files
# DEBUG: Sample files in 2002: ['1610612741vs.csv', '1610612764vs.csv', '1610612751vs.csv']
# DEBUG: 2002ps contains 33 CSV files
# DEBUG: Sample files in 2002ps: ['1610612751vs.csv', '1610612759vs.csv', '1610612738.csv']
# DEBUG: 2003 contains 59 CSV files
# DEBUG: Sample files in 2003: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2003ps contains 33 CSV files
# DEBUG: Sample files in 2003ps: ['1610612740vs.csv', '1610612751vs.csv', '1610612759vs.csv']
# DEBUG: 2004 contains 59 CSV files
# DEBUG: Sample files in 2004: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2004ps contains 33 CSV files
# DEBUG: Sample files in 2004ps: ['1610612740vs.csv', '1610612751vs.csv', '1610612743vs.csv']
# DEBUG: 2005 contains 61 CSV files
# DEBUG: Sample files in 2005: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2005ps contains 33 CSV files
# DEBUG: Sample files in 2005ps: ['1610612741vs.csv', '1610612764vs.csv', '1610612751vs.csv']
# DEBUG: 2006 contains 61 CSV files
# DEBUG: Sample files in 2006: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2006ps contains 33 CSV files
# DEBUG: Sample files in 2006ps: ['1610612741vs.csv', '1610612764vs.csv', '1610612751vs.csv']
# DEBUG: 2007 contains 61 CSV files
# DEBUG: Sample files in 2007: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2007ps contains 33 CSV files
# DEBUG: Sample files in 2007ps: ['1610612741vs.csv', '1610612764vs.csv', '1610612751vs.csv']
# DEBUG: 2008 contains 61 CSV files
# DEBUG: Sample files in 2008: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2008ps contains 33 CSV files
# DEBUG: Sample files in 2008ps: ['1610612764vs.csv', '1610612740vs.csv', '1610612743vs.csv']
# DEBUG: 2009 contains 61 CSV files
# DEBUG: Sample files in 2009: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2009ps contains 33 CSV files
# DEBUG: Sample files in 2009ps: ['1610612741vs.csv', '1610612740vs.csv', '1610612743vs.csv']
# DEBUG: 2010 contains 61 CSV files
# DEBUG: Sample files in 2010: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2010ps contains 33 CSV files
# DEBUG: Sample files in 2010ps: ['1610612741vs.csv', '1610612743vs.csv', '1610612759vs.csv']
# DEBUG: 2011 contains 61 CSV files
# DEBUG: Sample files in 2011: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2011ps contains 33 CSV files
# DEBUG: Sample files in 2011ps: ['1610612741vs.csv', '1610612740vs.csv', '1610612743vs.csv']
# DEBUG: 2012 contains 61 CSV files
# DEBUG: Sample files in 2012: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2012ps contains 33 CSV files
# DEBUG: Sample files in 2012ps: ['1610612741vs.csv', '1610612743vs.csv', '1610612759vs.csv']
# DEBUG: 2013 contains 61 CSV files
# DEBUG: Sample files in 2013: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2013ps contains 33 CSV files
# DEBUG: Sample files in 2013ps: ['1610612741vs.csv', '1610612751vs.csv', '1610612743vs.csv']
# DEBUG: 2014 contains 61 CSV files
# DEBUG: Sample files in 2014: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2014ps contains 33 CSV files
# DEBUG: Sample files in 2014ps: ['1610612741vs.csv', '1610612764vs.csv', '1610612751vs.csv']
# DEBUG: 2015 contains 61 CSV files
# DEBUG: Sample files in 2015: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2015ps contains 33 CSV files
# DEBUG: Sample files in 2015ps: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2016 contains 61 CSV files
# DEBUG: Sample files in 2016: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2016ps contains 33 CSV files
# DEBUG: Sample files in 2016ps: ['1610612759vs.csv', '1610612738.csv', '1610612765.csv']
# DEBUG: 2017 contains 61 CSV files
# DEBUG: Sample files in 2017: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2017ps contains 33 CSV files
# DEBUG: Sample files in 2017ps: ['1610612741vs.csv', '1610612764vs.csv', '1610612759vs.csv']
# DEBUG: 2018 contains 61 CSV files
# DEBUG: Sample files in 2018: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2018ps contains 33 CSV files
# DEBUG: Sample files in 2018ps: ['1610612764vs.csv', '1610612740vs.csv', '1610612759vs.csv']
# DEBUG: 2019 contains 61 CSV files
# DEBUG: Sample files in 2019: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2019ps contains 33 CSV files
# DEBUG: Sample files in 2019ps: ['1610612751vs.csv', '1610612743vs.csv', '1610612759vs.csv']
# DEBUG: 2020 contains 61 CSV files
# DEBUG: Sample files in 2020: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2020ps contains 33 CSV files
# DEBUG: Sample files in 2020ps: ['1610612751vs.csv', '1610612743vs.csv', '1610612738.csv']
# DEBUG: 2021 contains 61 CSV files
# DEBUG: Sample files in 2021: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2021ps contains 33 CSV files
# DEBUG: Sample files in 2021ps: ['1610612764vs.csv', '1610612751vs.csv', '1610612743vs.csv']
# DEBUG: 2022 contains 61 CSV files
# DEBUG: Sample files in 2022: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2022ps contains 33 CSV files
# DEBUG: Sample files in 2022ps: ['1610612741vs.csv', '1610612740vs.csv', '1610612751vs.csv']
# DEBUG: 2023 contains 61 CSV files
# DEBUG: Sample files in 2023: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2023ps contains 33 CSV files
# DEBUG: Sample files in 2023ps: ['1610612751vs.csv', '1610612743vs.csv', '1610612738.csv']
# DEBUG: 2024 contains 62 CSV files
# DEBUG: Sample files in 2024: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2024ps contains 61 CSV files
# DEBUG: Sample files in 2024ps: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2025 contains 61 CSV files
# DEBUG: Sample files in 2025: ['1610612741vs.csv', '1610612764vs.csv', '1610612740vs.csv']
# DEBUG: 2025ps contains 47 CSV files
# DEBUG: Sample files in 2025ps: ['1610612743vs.csv', '1610612738.csv', '1610612765.csv']
#
# Attempting to process years 2025 to 2025
# DEBUG: Looking for data from 2025 to 2025
# DEBUG: Processing year 2025
# DEBUG: Found file for Atlanta Hawks (1610612737): ../team/2025ps/1610612737.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from Atlanta Hawks
# DEBUG: Found file for Boston Celtics (1610612738): ../team/2025ps/1610612738.csv
# DEBUG: File shape: (913, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 104 unique games from Boston Celtics
# DEBUG: Found file for Cleveland Cavaliers (1610612739): ../team/2025ps/1610612739.csv
# DEBUG: File shape: (790, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 99 unique games from Cleveland Cavaliers
# DEBUG: Found file for New Orleans Pelicans (1610612740): ../team/2025ps/1610612740.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from New Orleans Pelicans
# DEBUG: Found file for Chicago Bulls (1610612741): ../team/2025ps/1610612741.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from Chicago Bulls
# DEBUG: Found file for Dallas Mavericks (1610612742): ../team/2025ps/1610612742.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from Dallas Mavericks
# DEBUG: Found file for Denver Nuggets (1610612743): ../team/2025ps/1610612743.csv
# DEBUG: File shape: (1211, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 122 unique games from Denver Nuggets
# DEBUG: Found file for Golden State Warriors (1610612744): ../team/2025ps/1610612744.csv
# DEBUG: File shape: (1026, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 126 unique games from Golden State Warriors
# DEBUG: Found file for Houston Rockets (1610612745): ../team/2025ps/1610612745.csv
# DEBUG: File shape: (576, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 66 unique games from Houston Rockets
# DEBUG: Found file for Los Angeles Clippers (1610612746): ../team/2025ps/1610612746.csv
# DEBUG: File shape: (592, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 70 unique games from Los Angeles Clippers
# DEBUG: Found file for Los Angeles Lakers (1610612747): ../team/2025ps/1610612747.csv
# DEBUG: File shape: (394, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 46 unique games from Los Angeles Lakers
# DEBUG: Found file for Miami Heat (1610612748): ../team/2025ps/1610612748.csv
# DEBUG: File shape: (326, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 41 unique games from Miami Heat
# DEBUG: Found file for Milwaukee Bucks (1610612749): ../team/2025ps/1610612749.csv
# DEBUG: File shape: (439, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 53 unique games from Milwaukee Bucks
# DEBUG: Found file for Minnesota Timberwolves (1610612750): ../team/2025ps/1610612750.csv
# DEBUG: File shape: (1282, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 143 unique games from Minnesota Timberwolves
# DEBUG: Found file for Brooklyn Nets (1610612751): ../team/2025ps/1610612751.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from Brooklyn Nets
# DEBUG: Found file for New York Knicks (1610612752): ../team/2025ps/1610612752.csv
# DEBUG: File shape: (1557, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 155 unique games from New York Knicks
# DEBUG: Found file for Orlando Magic (1610612753): ../team/2025ps/1610612753.csv
# DEBUG: File shape: (422, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 51 unique games from Orlando Magic
# DEBUG: Found file for Indiana Pacers (1610612754): ../team/2025ps/1610612754.csv
# DEBUG: File shape: (1367, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 167 unique games from Indiana Pacers
# DEBUG: Found file for Philadelphia 76ers (1610612755): ../team/2025ps/1610612755.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from Philadelphia 76ers
# DEBUG: Found file for Phoenix Suns (1610612756): ../team/2025ps/1610612756.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from Phoenix Suns
# DEBUG: Found file for Portland Trail Blazers (1610612757): ../team/2025ps/1610612757.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from Portland Trail Blazers
# DEBUG: Found file for Sacramento Kings (1610612758): ../team/2025ps/1610612758.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from Sacramento Kings
# DEBUG: Found file for San Antonio Spurs (1610612759): ../team/2025ps/1610612759.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from San Antonio Spurs
# DEBUG: Found file for Oklahoma City Thunder (1610612760): ../team/2025ps/1610612760.csv
# DEBUG: File shape: (1474, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 172 unique games from Oklahoma City Thunder
# DEBUG: Found file for Toronto Raptors (1610612761): ../team/2025ps/1610612761.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from Toronto Raptors
# DEBUG: Found file for Utah Jazz (1610612762): ../team/2025ps/1610612762.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from Utah Jazz
# DEBUG: Found file for Memphis Grizzlies (1610612763): ../team/2025ps/1610612763.csv
# DEBUG: File shape: (347, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 37 unique games from Memphis Grizzlies
# DEBUG: Found file for Washington Wizards (1610612764): ../team/2025ps/1610612764.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from Washington Wizards
# DEBUG: Found file for Detroit Pistons (1610612765): ../team/2025ps/1610612765.csv
# DEBUG: File shape: (496, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 50 unique games from Detroit Pistons
# DEBUG: Found file for Charlotte Hornets (1610612766): ../team/2025ps/1610612766.csv
# DEBUG: File shape: (0, 29), Columns: ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE', 'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE', 'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE', 'HTM', 'VTM', 'SHOT_ID', 'time', 'extra', 'PLAYERS_ON', 'assisted']
# DEBUG: Added 0 unique games from Charlotte Hornets
# DEBUG: Year 2025 - Found 30 team files
# DEBUG: Total unique games found: 77
# DEBUG: Date range: 20250419 to 20250531
# SUCCESS: Found game dates for 77 games
# DEBUG: Attempting to fetch 77 games
# DEBUG: Processing game 1/77
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400111.csv
# DEBUG: Successfully loaded CSV with 24 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400111.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400112.csv
# DEBUG: Successfully loaded CSV with 19 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400112.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400113.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400113.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400114.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400114.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400115.csv
# DEBUG: Successfully loaded CSV with 26 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400115.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400211.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400211.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400212.csv
# DEBUG: Successfully loaded CSV with 16 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400212.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400213.csv
# DEBUG: Successfully loaded CSV with 24 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400213.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400214.csv
# DEBUG: Successfully loaded CSV with 17 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400214.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400215.csv
# DEBUG: Successfully loaded CSV with 25 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400215.csv
# DEBUG: Processing game 11/77
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400216.csv
# DEBUG: Successfully loaded CSV with 26 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400216.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400101.csv
# DEBUG: Successfully loaded CSV with 27 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400101.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400102.csv
# DEBUG: Successfully loaded CSV with 19 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400102.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400103.csv
# DEBUG: Successfully loaded CSV with 23 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400103.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400104.csv
# DEBUG: Successfully loaded CSV with 26 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400104.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400201.csv
# DEBUG: Successfully loaded CSV with 20 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400201.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400202.csv
# DEBUG: Successfully loaded CSV with 20 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400202.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400203.csv
# DEBUG: Successfully loaded CSV with 26 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400203.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400204.csv
# DEBUG: Successfully loaded CSV with 29 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400204.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400205.csv
# DEBUG: Successfully loaded CSV with 20 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400205.csv
# DEBUG: Processing game 21/77
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400171.csv
# DEBUG: Successfully loaded CSV with 17 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400171.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400172.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400172.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400173.csv
# DEBUG: Successfully loaded CSV with 26 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400173.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400174.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400174.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400175.csv
# DEBUG: Successfully loaded CSV with 26 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400175.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400176.csv
# DEBUG: Successfully loaded CSV with 16 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400176.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400177.csv
# DEBUG: Successfully loaded CSV with 24 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400177.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400221.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400221.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400222.csv
# DEBUG: Successfully loaded CSV with 27 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400222.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400223.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400223.csv
# DEBUG: Processing game 31/77
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400224.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400224.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400225.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400225.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400226.csv
# DEBUG: Successfully loaded CSV with 21 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400226.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400227.csv
# DEBUG: Successfully loaded CSV with 25 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400227.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400151.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400151.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400152.csv
# DEBUG: Successfully loaded CSV with 28 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400152.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400153.csv
# DEBUG: Successfully loaded CSV with 17 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400153.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400154.csv
# DEBUG: Successfully loaded CSV with 19 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400154.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400155.csv
# DEBUG: Successfully loaded CSV with 28 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400155.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400156.csv
# DEBUG: Successfully loaded CSV with 27 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400156.csv
# DEBUG: Processing game 41/77
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400157.csv
# DEBUG: Successfully loaded CSV with 20 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400157.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400231.csv
# DEBUG: Successfully loaded CSV with 21 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400231.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400232.csv
# DEBUG: Successfully loaded CSV with 27 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400232.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400233.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400233.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400234.csv
# DEBUG: Successfully loaded CSV with 22 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400234.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400235.csv
# DEBUG: Successfully loaded CSV with 20 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400235.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400161.csv
# DEBUG: Successfully loaded CSV with 26 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400161.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400162.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400162.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400163.csv
# DEBUG: Successfully loaded CSV with 21 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400163.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400164.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400164.csv
# DEBUG: Processing game 51/77
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400165.csv
# DEBUG: Successfully loaded CSV with 16 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400165.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400131.csv
# DEBUG: Successfully loaded CSV with 24 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400131.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400132.csv
# DEBUG: Successfully loaded CSV with 20 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400132.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400133.csv
# DEBUG: Successfully loaded CSV with 25 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400133.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400134.csv
# DEBUG: Successfully loaded CSV with 26 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400134.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400135.csv
# DEBUG: Successfully loaded CSV with 20 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400135.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400311.csv
# DEBUG: Successfully loaded CSV with 26 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400311.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400312.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400312.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400313.csv
# DEBUG: Successfully loaded CSV with 28 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400313.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400314.csv
# DEBUG: Successfully loaded CSV with 19 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400314.csv
# DEBUG: Processing game 61/77
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400315.csv
# DEBUG: Successfully loaded CSV with 27 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400315.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400121.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400121.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400122.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400122.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400123.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400123.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400124.csv
# DEBUG: Successfully loaded CSV with 18 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400124.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400125.csv
# DEBUG: Successfully loaded CSV with 17 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400125.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400126.csv
# DEBUG: Successfully loaded CSV with 16 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400126.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400301.csv
# DEBUG: Successfully loaded CSV with 19 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400301.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400302.csv
# DEBUG: Successfully loaded CSV with 19 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400302.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400303.csv
# DEBUG: Successfully loaded CSV with 19 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400303.csv
# DEBUG: Processing game 71/77
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400304.csv
# DEBUG: Successfully loaded CSV with 20 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400304.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400305.csv
# DEBUG: Successfully loaded CSV with 24 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400305.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400306.csv
# DEBUG: Successfully loaded CSV with 26 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400306.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400141.csv
# DEBUG: Successfully loaded CSV with 25 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400141.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400142.csv
# DEBUG: Successfully loaded CSV with 19 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400142.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400143.csv
# DEBUG: Successfully loaded CSV with 20 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400143.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2025/42400144.csv
# DEBUG: Successfully loaded CSV with 21 rows, 432 columns
# DEBUG: Saved to game_data/2025_42400144.csv
# DEBUG: Fetch summary - Success: 77, Failed: 0
# DEBUG: Combined dataframe shape: (1645, 434)
# SUCCESS: Fetched 1645 rows of game data
# DEBUG: Processing dataframe with 1645 rows
# DEBUG: Unique team abbreviations in data: ['BOS', 'CLE', 'DEN', 'DET', 'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN', 'NYK', 'OKC', 'ORL']
# DEBUG: Unique HTM values: ['BOS', 'CLE', 'DEN', 'DET', 'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN', 'NYK', 'OKC', 'ORL']
# DEBUG: Unique VTM values: ['BOS', 'CLE', 'DEN', 'DET', 'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN', 'NYK', 'OKC', 'ORL']
# DEBUG: Home games: 813, Away games: 832, Games with no HTM: 0
# DEBUG: After home/away split: 1645 rows
# DEBUG: Opponent mapping frame: 154 rows
#        TEAM_ID      date opp_team
# 0   1610612738  20250420      ORL
# 12  1610612738  20250423      ORL
# 20  1610612753  20250425      BOS
# 30  1610612753  20250427      BOS
# 40  1610612738  20250429      ORL
# DEBUG: Team abbreviations available: 16 unique
# DEBUG: Team IDs available: 16 unique
# DEBUG: Sample team abbreviations: ['BOS', 'CLE', 'DEN', 'DET', 'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM']
# DEBUG: Sample team IDs: [np.int64(1610612738), np.int64(1610612739), np.int64(1610612743), np.int64(1610612744), np.int64(1610612745), np.int64(1610612746), np.int64(1610612747), np.int64(1610612748), np.int64(1610612749), np.int64(1610612750)]
# DEBUG: Team mapping created with 16 teams
# DEBUG: Team mapping sample: {'BOS': 1610612738, 'ORL': 1610612753, 'NYK': 1610612752, 'CLE': 1610612739, 'MIA': 1610612748}
# ...
# DEBUG: Successfully loaded CSV with 18 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300231.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300232.csv
# DEBUG: Successfully loaded CSV with 26 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300232.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300233.csv
# DEBUG: Successfully loaded CSV with 26 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300233.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300234.csv
# DEBUG: Successfully loaded CSV with 16 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300234.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300235.csv
# DEBUG: Successfully loaded CSV with 17 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300235.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300236.csv
# DEBUG: Successfully loaded CSV with 27 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300236.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300237.csv
# DEBUG: Successfully loaded CSV with 16 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300237.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300121.csv
# DEBUG: Successfully loaded CSV with 20 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300121.csv
# DEBUG: Processing game 61/82
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300122.csv
# DEBUG: Successfully loaded CSV with 22 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300122.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300123.csv
# DEBUG: Successfully loaded CSV with 19 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300123.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300124.csv
# DEBUG: Successfully loaded CSV with 23 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300124.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300125.csv
# DEBUG: Successfully loaded CSV with 21 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300125.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300126.csv
# DEBUG: Successfully loaded CSV with 25 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300126.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300161.csv
# DEBUG: Successfully loaded CSV with 26 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300161.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300162.csv
# DEBUG: Successfully loaded CSV with 24 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300162.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300163.csv
# DEBUG: Successfully loaded CSV with 24 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300163.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300164.csv
# DEBUG: Successfully loaded CSV with 16 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300164.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300111.csv
# DEBUG: Successfully loaded CSV with 17 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300111.csv
# DEBUG: Processing game 71/82
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300112.csv
# DEBUG: Successfully loaded CSV with 16 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300112.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300113.csv
# DEBUG: Successfully loaded CSV with 18 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300113.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300114.csv
# DEBUG: Successfully loaded CSV with 17 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300114.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300115.csv
# DEBUG: Successfully loaded CSV with 15 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300115.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300116.csv
# DEBUG: Successfully loaded CSV with 16 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300116.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300211.csv
# DEBUG: Successfully loaded CSV with 17 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300211.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300212.csv
# DEBUG: Successfully loaded CSV with 17 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300212.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300213.csv
# DEBUG: Successfully loaded CSV with 17 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300213.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300214.csv
# DEBUG: Successfully loaded CSV with 24 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300214.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300215.csv
# DEBUG: Successfully loaded CSV with 25 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300215.csv
# DEBUG: Processing game 81/82
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300216.csv
# DEBUG: Successfully loaded CSV with 24 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300216.csv
# DEBUG: Fetching https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/game_report/2024/42300217.csv
# DEBUG: Successfully loaded CSV with 23 rows, 421 columns
# DEBUG: Saved to game_data/2024_42300217.csv
# DEBUG: Fetch summary - Success: 82, Failed: 0
# DEBUG: Combined dataframe shape: (1685, 421)
# SUCCESS: Fetched 1685 rows of game data
# DEBUG: Processing dataframe with 1685 rows
# DEBUG: Unique team abbreviations in data: ['BOS', 'CLE', 'DAL', 'DEN', 'IND', 'LAC', 'LAL', 'MIA', 'MIL', 'MIN', 'NOP', 'NYK', 'OKC', 'ORL', 'PHI', 'PHX']
# DEBUG: Unique HTM values: ['BOS', 'CLE', 'DAL', 'DEN', 'IND', 'LAC', 'LAL', 'MIA', 'MIL', 'MIN', 'NOP', 'NYK', 'OKC', 'ORL', 'PHI', 'PHX']
# DEBUG: Unique VTM values: ['BOS', 'CLE', 'DAL', 'DEN', 'IND', 'LAC', 'LAL', 'MIA', 'MIL', 'MIN', 'NOP', 'NYK', 'OKC', 'ORL', 'PHI', 'PHX']
# DEBUG: Home games: 838, Away games: 847, Games with no HTM: 0
# DEBUG: After home/away split: 1685 rows
# DEBUG: Opponent mapping frame: 164 rows
#        TEAM_ID      date opp_team opp_team
# 0   1610612738  20240421      MIA      MIA
# 8   1610612738  20240424      MIA      MIA
# 16  1610612748  20240427      BOS      BOS
# 27  1610612748  20240429      BOS      BOS
# 37  1610612738  20240501      MIA      MIA
# DEBUG: Team abbreviations available: 16 unique
# DEBUG: Team IDs available: 16 unique
# DEBUG: Sample team abbreviations: ['BOS', 'CLE', 'DAL', 'DEN', 'IND', 'LAC', 'LAL', 'MIA', 'MIL', 'MIN']
# DEBUG: Sample team IDs: [np.int64(1610612738), np.int64(1610612739), np.int64(1610612740), np.int64(1610612742), np.int64(1610612743), np.int64(1610612746), np.int64(1610612747), np.int64(1610612748), np.int64(1610612749), np.int64(1610612750)]
# DEBUG: Team mapping created with 16 teams
# DEBUG: Team mapping sample: {'BOS': 1610612738, 'MIA': 1610612748, 'CLE': 1610612739, 'IND': 1610612754, 'DAL': 1610612742}
# DEBUG: DataFrame columns before player index creation: ['PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID', 'TEAM_ABBREVIATION', 'AGE', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2', 'TD3', 'WNBA_FANTASY_PTS', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK', 'TD3_RANK', 'WNBA_FANTASY_PTS_RANK', 'DEF_RATING_RANK', 'PIE', 'FGM_PG', 'FGA_PG', 'E_OFF_RATING', 'DREB_PCT_RANK', 'E_DEF_RATING', 'PACE_RANK', 'PACE', 'E_NET_RATING_RANK', 'EFG_PCT', 'sp_work_OFF_RATING', 'OFF_RATING_RANK', 'sp_work_NET_RATING', 'USG_PCT_RANK', 'AST_PCT_RANK', 'POSS', 'sp_work_PACE_RANK', 'sp_work_NET_RATING_RANK', 'DEF_RATING', 'sp_work_DEF_RATING_RANK', 'DREB_PCT', 'E_TOV_PCT_RANK', 'sp_work_PACE', 'sp_work_DEF_RATING', 'REB_PCT', 'USG_PCT', 'AST_RATIO', 'NET_RATING', 'AST_TO_RANK', 'E_PACE', 'EFG_PCT_RANK', 'FGM_PG_RANK', 'REB_PCT_RANK', 'E_TOV_PCT', 'AST_RATIO_RANK', 'PACE_PER40', 'PIE_RANK', 'AST_PCT', 'OREB_PCT', 'TM_TOV_PCT_RANK', 'TS_PCT_RANK', 'AST_TO', 'OFF_RATING', 'E_USG_PCT_RANK', 'E_USG_PCT', 'E_DEF_RATING_RANK', 'OREB_PCT_RANK', 'NET_RATING_RANK', 'E_PACE_RANK', 'TS_PCT', 'sp_work_OFF_RATING_RANK', 'TM_TOV_PCT', 'FGA_PG_RANK', 'E_NET_RATING', 'E_OFF_RATING_RANK', 'BACKCOURT_FG_PCT', 'LEFT_CORNER_3_FG_PCT', 'MID_FGM', 'RA_FG_PCT', 'CORNER_3_FGA', 'RA_FGA', 'ITP_FGA', 'MID_FGA', 'ABOVE_BREAK_3_FGM', 'ABOVE_BREAK_3_FGA', 'MID_FG_PCT', 'CORNER_3_FG_PCT', 'RA_FGM', 'RIGHT_CORNER_3_FG_PCT', 'BACKCOURT_FGA', 'RIGHT_CORNER_3_FGM', 'CORNER_3_FGM', 'BACKCOURT_FGM', 'ITP_FG_PCT', 'ITP_FGM', 'ABOVE_BREAK_3_FG_PCT', 'RIGHT_CORNER_3_FGA', 'LEFT_CORNER_3_FGM', 'LEFT_CORNER_3_FGA', 'FGM_35_39', 'FGM_10_14', 'FGP_20_24', 'FGA_15_19', 'FGM_20_24', 'FGM_40_PLUS', 'FGP_15_19', 'FGP_35_39', 'FGP_25_29', 'FGA_30_34', 'FGM_LT_5', 'FGA_LT_5', 'FGA_20_24', 'FGP_30_34', 'TEAM_ABBR', 'FGM_30_34', 'FGP_LT_5', 'FGM_15_19', 'FGP_40_PLUS', 'FGA_10_14', 'FGA_25_29', 'FGP_10_14', 'FGA_5_9', 'FGA_35_39', 'FGP_5_9', 'FGA_40_PLUS', 'FGM_5_9', 'FGM_25_29', 'year', 'date', 'PASSES_MADE', 'AST_TO_PASS_PCT', 'PASSES_RECEIVED', 'FT_AST', 'AST_PTS_CREATED', 'POTENTIAL_AST', 'AST_TO_PASS_PCT_ADJ', 'SECONDARY_AST', 'AST_ADJ', 'DRIVE_TOV_PCT', 'DRIVE_PF', 'DRIVE_FTM', 'DRIVES', 'DRIVE_PASSES_PCT', 'DRIVE_TOV', 'DRIVE_AST_PCT', 'DRIVE_FT_PCT', 'DRIVE_PF_PCT', 'DRIVE_FG_PCT', 'DRIVE_FGM', 'DRIVE_PASSES', 'DRIVE_FGA', 'DRIVE_FTA', 'DRIVE_PTS', 'DRIVE_AST', 'DRIVE_PTS_PCT', 'TOUCHES', 'PTS_PER_POST_TOUCH', 'FRONT_CT_TOUCHES', 'ELBOW_TOUCHES', 'POINTS', 'PAINT_TOUCHES', 'PTS_PER_PAINT_TOUCH', 'AVG_DRIB_PER_TOUCH', 'PTS_PER_ELBOW_TOUCH', 'AVG_SEC_PER_TOUCH', 'POST_TOUCHES', 'TIME_OF_POSS', 'PTS_PER_TOUCH', 'REB_CHANCE_PCT', 'OREB_CONTEST', 'AVG_OREB_DIST', 'OREB_CONTEST_PCT', 'OREB_CHANCES', 'REB_CONTEST_PCT', 'REB_CHANCE_DEFER', 'DREB_CONTEST_PCT', 'DREB_CHANCE_PCT', 'AVG_REB_DIST', 'AVG_DREB_DIST', 'REB_CONTEST', 'DREB_CHANCE_PCT_ADJ', 'DREB_CHANCE_DEFER', 'REB_UNCONTEST', 'DREB_CONTEST', 'OREB_CHANCE_PCT', 'OREB_CHANCE_DEFER', 'DREB_CHANCES', 'OREB_UNCONTEST', 'REB_CHANCE_PCT_ADJ', 'OREB_CHANCE_PCT_ADJ', 'DREB_UNCONTEST', 'REB_CHANCES', 'very_tight_FG2A_FREQUENCY', 'very_tight_EFG_PCT', 'very_tight_FG3A_FREQUENCY', 'very_tight_FG3A', 'very_tight_FGM', 'very_tight_FG2_PCT', 'PLAYER_LAST_TEAM_ABBREVIATION', 'very_tight_FGA', 'very_tight_FG3_PCT', 'very_tight_FG3M', 'very_tight_FG2M', 'G', 'PLAYER_LAST_TEAM_ID', 'very_tight_FG2A', 'very_tight_FGA_FREQUENCY', 'very_tight_FG_PCT', 'tight_FGA', 'tight_FGA_FREQUENCY', 'tight_FG2_PCT', 'tight_FG2A_FREQUENCY', 'tight_FG2A', 'tight_EFG_PCT', 'tight_FG3A', 'tigh ...
# DEBUG: DataFrame shape before player index creation: (1685, 420)
# DEBUG: Player index shape: (1685, 7)
# DEBUG: Player index columns: ['PLAYER_NAME', 'PLAYER_ID', 'team', 'TEAM_ID', 'opp_team', 'opp_team', 'year']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 377
#     375 # Test with 2024 (not working)
#     376 print("Testing 2024 (problematic):")
# --> 377 result_2024 = run_pipeline(2024, 2025)
#     379 print("\n" + "="*80 + "\n")
#     381 # Test with 2023 (not working)
#
# Cell In[18], line 363, in run_pipeline(start_year, end_year)
#     361 else:
#     362     print(f"SUCCESS: Fetched {len(raw_df)} rows of game data")
# --> 363     processed_df = process_and_save_series_data(raw_df, dates)
#     364     print("PIPELINE COMPLETED SUCCESSFULLY")
#     365     return processed_df
#
# Cell In[18], line 209, in process_and_save_series_data(df, dateframe)
#     207 print(f"DEBUG: Player index columns: {list(player_index.columns)}")
#     208 if 'opp_team' in player_index.columns:
# --> 209     opp_team_counts = player_index['opp_team'].value_counts()
#     210     print(f"DEBUG: Opponent teams before mapping: {opp_team_counts.head()}")
#     211     print(f"DEBUG: Total non-null opponent teams: {player_index['opp_team'].notna().sum()}")
#
# File ~/basketball/contract/salaryapp/venv/lib/python3.12/site-packages/pandas/core/frame.py:7509, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    7506     subset = self.columns.tolist()
#    7508 name = "proportion" if normalize else "count"
# -> 7509 counts = self.groupby(subset, dropna=dropna, observed=False)._grouper.size()
#    7510 counts.name = name
#    7512 if sort:
#
# File ~/basketball/contract/salaryapp/venv/lib/python3.12/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~/basketball/contract/salaryapp/venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~/basketball/contract/salaryapp/venv/lib/python3.12/site-packages/pandas/core/groupby/grouper.py:1038, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1034     in_axis, name, gpr = True, gpr, obj[gpr]
#    1035     if gpr.ndim != 1:
#    1036         # non-unique columns; raise here to get the name in the
#    1037         # exception message
# -> 1038         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#    1039     exclusions.add(name)
#    1040 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'opp_team' not 1-dimensional
