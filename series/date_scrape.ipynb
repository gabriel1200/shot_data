# %%
import pandas as pd
import requests
import os
from nba_api.stats.static import players,teams

# %%
dates[dates.team=='CHA']
# Out:
#        GAME_ID     TEAM_ID  HTM  VTM      date   season  playoffs team  \
# 0     49600001  1610612766  NYK  CHA  19970424  1996-97      True  CHA
# 78    49600010  1610612766  NYK  CHA  19970426  1996-97      True  CHA
# 155   49600017  1610612766  CHA  NYK  19970428  1996-97      True  CHA
# 0     29600016  1610612766  CHA  TOR  19961102  1996-97     False  CHA
# 81    29600025  1610612766  NYK  CHA  19961103  1996-97     False  CHA
# ...        ...         ...  ...  ...       ...      ...       ...  ...
# 6718  22301159  1610612766  ATL  CHA  20240410  2023-24     False  CHA
# 6797  22301173  1610612766  BOS  CHA  20240412  2023-24     False  CHA
# 6873  22301187  1610612766  CLE  CHA  20240414  2023-24     False  CHA
# 6964  22301211  1610612766  CHI  CHA  20231206  2023-24     False  CHA
# 7054  22301216  1610612766  CHA  TOR  20231208  2023-24     False  CHA
#
#      opp_team
# 0         NYK
# 78        NYK
# 155       NYK
# 0         TOR
# 81        NYK
# ...       ...
# ...
