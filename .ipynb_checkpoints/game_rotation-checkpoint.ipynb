# %%
from nba_api.stats.endpoints import gamerotation, leaguegamefinder
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from nba_api.stats.static import teams
# Out:
# C:\Users\gaber\anaconda3\envs\myenvpython310\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.15) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
def game_rotation(game_id,team_id):
    frames = gamerotation.GameRotation(game_id = game_id,league_id = '00').get_data_frames()

    if frames[0].iloc[0]['TEAM_ID'] ==team_id:
        frames = frames[0]
    else:
        frames= frames[1]

    frames['fullname']= frames['PLAYER_FIRST']+ ' '+ frames['PLAYER_LAST']
    frames = frames[['OUT_TIME_REAL','fullname','IN_TIME_REAL','PT_DIFF']]
    frames['OUT_TIME_REAL'] = frames['OUT_TIME_REAL']/10
    frames['IN_TIME_REAL'] = frames['IN_TIME_REAL']/10
    frames['span']= frames['OUT_TIME_REAL'] -frames['IN_TIME_REAL']
    df = frames
    return df
def team_games(team_acr,season):
    nba_teams = teams.get_teams()
    # Select the dictionary for the Celtics, which contains their team ID
    team = [team for team in nba_teams if team['abbreviation'] == team_acr][0]
    team_id = team['id']
    gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=team_id,season_nullable=season)
    # The first DataFrame of those returned is what we want.
    games = gamefinder.get_data_frames()[0]
    return games,team_id

# %%
date = '2023-04-18'



team_acr = 'ATL'



games,team_id = team_games(team_acr,'2022-23')
game = games[games['GAME_DATE']==date]
game_id = game.iloc[0]['GAME_ID']

scoreline = str(game['PTS'].values[0])+ '-' +str(round(game['PTS'].values[0]-game['PLUS_MINUS'].values[0]))

opp = game['MATCHUP'].values[0][-3:]
title = team_acr+' '+scoreline+' '+opp
#title = team_acr +': '+ date
df = game_rotation(game_id,team_id)
df['IN_TIME_REAL']/=60
df['OUT_TIME_REAL']/=60
df['span']/=60
df = df.sort_values(by = ['fullname'],ascending = False)
df['fullname']+='  '

# %%
games['SEASON_ID']
# Out:
# 0     42022
# 1     42022
# 2     42022
# 3     42022
# 4     42022
#       ...
# 88    22022
# 89    12022
# 90    12022
# 91    12022
# 92    12022
# Name: SEASON_ID, Length: 93, dtype: object

# %%
logs = games['GAME_ID'].tolist()
#logs
logs = logs[0:10]
logs
# Out:
# ['0042200116',
#  '0042200115',
#  '0042200114',
#  '0042200113',
#  '0042200112',
#  '0042200111',
#  '0052200101',
#  '0022201216',
#  '0022201205',
#  '0022201191']

# %%
frames = []
for game in logs:
    frame = gamerotation.GameRotation(game_id = game,league_id = '00').get_data_frames()[0]
    frames.append(frame)

frames
# Out:
# [       GAME_ID     TEAM_ID TEAM_CITY TEAM_NAME  PERSON_ID PLAYER_FIRST  \
#  0   0042200116  1610612738    Boston   Celtics     201143           Al
#  1   0042200116  1610612738    Boston   Celtics     201143           Al
#  2   0042200116  1610612738    Boston   Celtics     201143           Al
#  3   0042200116  1610612738    Boston   Celtics     201143           Al
#  4   0042200116  1610612738    Boston   Celtics     201143           Al
#  5   0042200116  1610612738    Boston   Celtics     203935       Marcus
#  6   0042200116  1610612738    Boston   Celtics     203935       Marcus
#  7   0042200116  1610612738    Boston   Celtics     203935       Marcus
#  8   0042200116  1610612738    Boston   Celtics     203935       Marcus
#  9   0042200116  1610612738    Boston   Celtics     203935       Marcus
#  10  0042200116  1610612738    Boston   Celtics    1627759       Jaylen
#  11  0042200116  1610612738    Boston   Celtics    1627759       Jaylen
# ...

# %%
def graph_rotation(df,title):

    fig = go.Figure(
        layout = {
            'barmode': 'stack',
            'xaxis': {'automargin': True},
            'yaxis': {'automargin': True}}#, 'categoryorder': 'category ascending'}}
    )

    for character, character_df in df.groupby('fullname',sort = False):


        fig.add_trace(
            go.Bar(
                    x=character_df.span,
                    y=character_df.fullname,
                    base=character_df.IN_TIME_REAL,
                    orientation='h',
                    showlegend=False,

                    marker=dict(color = character_df.PT_DIFF,
                               coloraxis='coloraxis'),
                    #marker_color character_df.PT_DIFF,
                    #color_continuous_scale='Bluered_r',
                    name=character))
    fig.update_xaxes(
            range =(0,df['OUT_TIME_REAL'].max()),
            ticks="outside",
            tickson="boundaries",
            tickvals =[i for i in range(0,int(df['OUT_TIME_REAL'].max())+1,2)],
            tickfont =dict(size = 15),
            #tickangle = 10
        )
    fig.update_yaxes(
            tickvals = df.fullname,
            tickmode = 'linear',
            title_standoff = 50


         )

    fig.update_layout(width=1600, height=1000,paper_bgcolor='#fcf5f1',plot_bgcolor='#fcf5f1',bargroupgap=0.0,bargap = 0,


                      title = title,
                      title_x=0.5,
                      font=dict(
                family="Arial Black",

                size=18,
                color="Black"
            ))
    fig.update_layout(coloraxis = {'colorscale':'Pinkyl','colorbar':dict(title=dict(text = '+/-'))})
    return fig
#fig.update_coloraxes(colorbar=sm)
    #plot.grid(axis='y',color='lightgrey')
'''
sm = plt.cm.ScalarMappable(cmap=c_scale, norm=norm)
sm.set_array([])
cbar = plot.figure.colorbar(sm)
cbar.ax.set_title('PPP',fontdict= {'color':'white','size':'23'},y=1,rotation=0,pad =20)
    
#sm = plt.cm.ScalarMappable(cmap=c_scale, norm=norm)
#sm.set_array([])
#cbar = plot.figure.colorbar(sm)
fig.update_xaxes(gridwidth=4, gridcolor='#f9f9f9')
#fig.update_yaxes(showgrid=True, gridwidth=4, gridcolor='White')
#fig.update_xaxes(showline=True, linewidth=2, linecolor='black')
'''
graph_rotation(df,title).show()

# %%
df

# %%
df.groupby('fullname')

# %%
import plotly.express as px
import pandas as pd

df['IN_TIME_REAL'] = '2009-02-28'+df['IN_TIME_REAL'].astype(str)


fig = px.timeline(df, x_start="IN_TIME_REAL", x_end="OUT_TIME_REAL", y="fullname", color="PT_DIFF")

fig.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define the data


# Convert the times to seconds
df['start'] = df['IN_TIME_REAL']
df['end'] = df['OUT_TIME_REAL']
df['player'] = df['fullname']
# Group the data by player
grouped = df.groupby('player')
players = df['player'].unique().tolist()
# Create the figure and axes objects
fig, ax = plt.subplots(figsize=(30, 14))

# Plot the horizontal bars for each player
for i, player in enumerate(players):
    player_data = grouped.get_group(player)
    ax.broken_barh([(player_data['start'].iloc[j], player_data['end'].iloc[j] - player_data['start'].iloc[j])
                    for j in range(len(player_data))],
                   (i*10, 9), facecolors='darkred')
    

# Set the x-axis limits and tick labels
x_min = df['start'].min()
x_max = df['end'].max()
step = 1
#ax.set_xlim(x_min, x_max+100)
ax.set_xticks(range(int(x_min), int(x_max)+1, step))
ax.set_xticklabels([x for x in range(int(x_min), int(x_max)+1)])

# Set the y-axis limits and tick labels
ax.set_xlim(x_min,x_max)
ax.set_ylim(0, len(players)*10)
ax.set_yticks(range(0, len(players)*10, 10))
ax.set_yticklabels(players)
#ax.tick_params(top=True, labeltop=True)
# Add labels and title
ax.set_xlabel('Time')
ax.set_ylabel('Player')
ax.set_title('NBA Player Rotation Minutes')
ax.tick_params(axis='y', which='major', labelsize=20)
ax.tick_params(axis='x', which='major', labelsize=15)
# Show the plot
ax.grid(which='major', color='grey', linewidth=1.2)
plt.yticks(ha='right')

plt.show()

# %%
import plotly.graph_objs as go

def broken_bars(xstart, xwidth, ystart, yh, colors):
    #xstart - list of x-start coord for each bar
    #xwidth = list of bar widths
    #ystart - number y-start coord for each bar
    #yh - number- height of eah bar
    #colors = list of bar colors
    
    if len(xstart) != len(xwidth) or  len(xstart) != len(colors):
        raise ValueError('xstart, xwidth and colors must have the same length')
    shapes = []    
    for k in range(len(xstart)):
        shapes.append(dict(type="rect",
                           x0=xstart[k],
                           y0=ystart,
                           x1=xstart[k] + xwidth[k],
                           y1=ystart+yh,
                           fillcolor=colors[k],
                           line_color=colors[k]))
    return shapes    
# taken from https://community.plotly.com/t/broken-barh-plot/36496/2
fig = go.Figure()
fig.update_layout(width=1000, height=625,
                  xaxis_range = [xmin,xmax],
                  yaxis_range = [0,len(players)],
                  shapes=broken_bars([10, 100, 130 ], [50, 20, 10], 20, 9, 
                                     colors=['orange', 'green', 'red' ]))

# %%
raw_game = f'https://cdn.nba.com/static/json/liveData/playbyplay/playbyplay_{game_id}.json'
page = requests.get(raw_game)
j = json.loads(page.content)
df = pd.DataFrame(j['game']['actions'])

# %%
x_max = df['end'].max()

# %%
x_max

# %%
import plotly.figure_factory as ff
df['Task'] = df['fullname']
df['Start'] = df['start']
df['Finish'] = df['end']
fig = ff.create_gantt(df)
fig.show()

# %%
df.columns
