# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import pandas as pd
import numpy as np
import unidecode
import requests
import time

headers = {
    'Host': 'stats.nba.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br',
    'x-nba-stats-origin': 'stats',
    'x-nba-stats-token': 'true',
    'Connection': 'keep-alive',
    'Referer': 'https://stats.nba.com/',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache'
}

df_list = []

for ssn in ['2024-25']:

    # Synergy Playtypes
    playtypes = [
        'Isolation', 'PRBallHandler', 'PRRollMan', 'Spotup', 'Postup', 'Transition', 'Handoff', 'Cut', 'OffScreen', 'Misc'
    ]

    synergy_data = []

    for playtype in playtypes:
        url = f'https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=Totals&PlayType={playtype}&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear={ssn}&TypeGrouping=offensive'
        response = requests.get(url, headers=headers).json()
        time.sleep(1)

        data = response['resultSets'][0]['rowSet']
        columns = response['resultSets'][0]['headers']

        df = pd.DataFrame.from_records(data, columns=columns)

        # Rename columns for clarity
        df.rename(columns={
            'POSS_PCT': f'{playtype}_POSS_PCT',
            'EFG_PCT': f'{playtype}_EFG_PCT',
            'PTS': f'{playtype}_PTS'
        }, inplace=True)

        # Weighted averages and summing points
        g = df.groupby(['PLAYER_NAME'])
        df = pd.merge(
            g.apply(lambda x: pd.Series(
                np.average(x[[f'{playtype}_POSS_PCT', f'{playtype}_EFG_PCT']], weights=x['POSS'], axis=0),
                [f'{playtype}_POSS_PCT', f'{playtype}_EFG_PCT']
            )).reset_index(drop=False),
            pd.DataFrame(g.sum()[f'{playtype}_PTS']).reset_index(drop=False),
            on='PLAYER_NAME'
        )

        synergy_data.append(df)

    # Merge all synergy playtype data
    synergy_df = synergy_data[0]
    for df in synergy_data[1:]:
        synergy_df = pd.merge(synergy_df, df, on='PLAYER_NAME', how='outer')

    synergy_df.fillna(0, inplace=True)
    synergy_df['SEASON'] = ssn

    df_list.append(synergy_df)
    print(f"Year {ssn} is finished.")

# Combine all seasons
df = pd.concat(df_list).reset_index(drop=True)

# Preview the data
print(df.head())


# In[3]:


from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#testdf = df[(df.MPG > 23) & (df.GP > 15) & (df.SEASON == '2022-23')].reset_index(drop=True)
testdf = df.reset_index(drop=True)

features = [x for x in df.columns if (x != 'PLAYER_NAME') &  (x != 'POSITION') & (x != 'SEASON')]

x = testdf.loc[:, features].values
y = testdf.loc[:,['PLAYER_NAME']].values

x = StandardScaler().fit_transform(x) # standardize all values

pca = PCA(n_components=0.99)
principalComponents = pca.fit_transform(x)

plt.figure(figsize=(10,65))
plt.title('2024-25 NBA Hierarchical Clustering Dendrogram')
dend = shc.dendrogram(shc.linkage(x, method='ward'), labels=list(testdf.PLAYER_NAME), orientation='left')

plt.yticks(fontsize=8)
plt.xlabel('Height')

plt.tight_layout()

# Save the plot in PNG format
plt.savefig("nba_hierarchical_clustering_dendrogram.png", format='png', dpi=300)

# Optionally, display the plot as well
plt.show()


# In[11]:


from scipy.cluster.hierarchy import fcluster
from scipy.cluster.hierarchy import linkage
import pandas as pd

# Compute linkage matrix (using Ward's method as in your dendrogram)
linkage_matrix = shc.linkage(x, method='ward')

# Set a distance threshold (adjust based on your dendrogram)
distance_threshold = 30  # Adjust based on large vertical gaps in the dendrogram

# Find clusters
clusters = fcluster(linkage_matrix, distance_threshold, criterion='distance')

# Add cluster labels to the dataframe
testdf['Cluster'] = clusters

# Print cluster counts
print(testdf['Cluster'].value_counts())

# Save the cluster assignments
testdf[['PLAYER_NAME', 'Cluster']].to_csv('nba_hierarchical_clusters.csv', index=False)

# Exclude non-numeric columns for the cluster summary
numeric_features = testdf.select_dtypes(include=[np.number])  # Keep only numeric columns
numeric_features['Cluster'] = testdf['Cluster']  # Add Cluster column back

# Calculate the mean for each numeric feature grouped by Cluster
cluster_summary = numeric_features.groupby('Cluster').mean()

# Print the feature summary for each cluster
for cluster_id in cluster_summary.index:
    print(f"Cluster {cluster_id} Summary:")
    print(cluster_summary.loc[cluster_id])
    print("-" * 40)

# Optionally, save the cluster summary to a CSV
cluster_summary.to_csv('nba_hierarchical_cluster_summary.csv', index=True)


# In[16]:


from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import numpy as np

# Use the processed data after PCA
x = testdf.loc[:, features].values
x = StandardScaler().fit_transform(x)
pca = PCA(n_components=0.99)



principalComponents = pca.fit_transform(x)
print('EXPLAIN SECTION')

explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance = explained_variance_ratio.cumsum()

# Display explained variance ratio
print("Explained Variance Ratio:", explained_variance_ratio)
print("Cumulative Explained Variance:", cumulative_variance)

# PCA components (loadings)
loadings = pca.components_

# Create a DataFrame for loadings
feature_names = your_data.columns
loadings_df = pd.DataFrame(loadings, columns=feature_names, index=[f"PC{i+1}" for i in range(len(loadings))])

# Display the PCA loadings
print("\nPCA Loadings (Contributions of Original Features):")
print(loadings_df)

# Find the most influential features for the first principal component
top_features_pc1 = loadings_df.loc["PC1"].abs().sort_values(ascending=False)
print("\nTop Features for PC1:")
print(top_features_pc1)
# Determine optimal number of clusters using the elbow method
inertia = []
silhouette_scores = []
k_values = range(2, 30)  # Testing for 2 to 10 clusters

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10, max_iter=500)
    kmeans.fit(principalComponents)
    inertia.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(principalComponents, kmeans.labels_))

# Plotting the Elbow Method
plt.figure(figsize=(10, 5))
plt.plot(k_values, inertia, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# Plotting Silhouette Scores
plt.figure(figsize=(10, 5))
plt.plot(k_values, silhouette_scores, marker='o', color='green')
plt.title('Silhouette Scores for Different k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.grid()
plt.show()

# Choose the optimal number of clusters (e.g., based on plots)
optimal_k = 13  # Replace with the chosen k based on visual inspection

# Fit K-Means with the optimal number of clusters
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10, max_iter=500)
kmeans.fit(principalComponents)

# Add cluster labels to the dataframe
testdf['Cluster'] = kmeans.labels_

# Save results to a CSV (optional)
testdf[['PLAYER_NAME', 'Cluster']].to_csv('nba_kmeans_clusters.csv', index=False)

# Visualize the clusters in the first two PCA components
plt.figure(figsize=(10, 7))
for cluster in range(optimal_k):
    cluster_points = principalComponents[kmeans.labels_ == cluster]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {cluster}')

plt.title('K-Means Clustering Visualization')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend()
plt.grid()
plt.show()


# In[20]:


import plotly.express as px
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# Use the processed data
x = testdf.loc[:, features].values
x = StandardScaler().fit_transform(x)
pca = PCA(n_components=0.99)
principalComponents = pca.fit_transform(x)

# Choose the optimal number of clusters
optimal_k = 13
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10, max_iter=500)
kmeans.fit(principalComponents)

# Add cluster labels and PCA components to the dataframe
testdf['Cluster'] = kmeans.labels_
testdf['PCA1'] = principalComponents[:, 0]  # First principal component
testdf['PCA2'] = principalComponents[:, 1]  # Second principal component

# Define consistent color mapping for clusters
color_map = px.colors.qualitative.Set1  # Adjust this if more than 10 clusters
cluster_colors = {cluster: color_map[i % len(color_map)] for i, cluster in enumerate(sorted(testdf['Cluster'].unique()))}

# Create the base scatter plot
fig = px.scatter(
    testdf,
    x='PCA1',
    y='PCA2',
    color='Cluster',
    color_discrete_map=cluster_colors,
    hover_data=['PLAYER_NAME'],  # Show player names on hover
    title='K-Means Clustering Visualization',
    labels={'PCA1': 'Principal Component 1', 'PCA2': 'Principal Component 2'},
)

# Add a dropdown menu to filter clusters
fig.update_layout(
    updatemenus=[
        {
            "buttons": [
                {
                    "label": f"Show Cluster {cluster}",
                    "method": "update",
                    "args": [
                        {
                            "marker": {"opacity": [1 if c == cluster else 0.2 for c in testdf['Cluster']]},
                        },
                        {"title": f"K-Means Clustering: Cluster {cluster} Highlighted"},
                    ],
                }
                for cluster in sorted(testdf['Cluster'].unique())
            ]
            + [
                {
                    "label": "Show All Clusters",
                    "method": "update",
                    "args": [
                        {
                            "marker": {"opacity": [1 for _ in testdf['Cluster']]},
                        },
                        {"title": "K-Means Clustering: All Clusters"},
                    ],
                }
            ],
            "direction": "down",
            "showactive": True,
        }
    ]
)

# Show the plot
fig.show()


# In[17]:


# Exclude non-numeric columns for the feature summary
numeric_features = testdf.select_dtypes(include=[np.number])

# Add the Cluster column back to the numeric_features dataframe
numeric_features['Cluster'] = testdf['Cluster']

# Calculate the mean for each numeric feature grouped by Cluster
feature_summary = numeric_features.groupby('Cluster').mean()

# Print the feature summary for each cluster
for cluster_id in range(optimal_k):
    print(f"Cluster {cluster_id} Summary:")
    print(feature_summary.loc[cluster_id])
    print("-" * 40)

# Optionally, save the feature summary to a CSV
feature_summary.to_csv('cluster_feature_summary.csv', index=True)



# In[7]:





# In[ ]:





# In[17]:
# Out:
# /tmp/ipykernel_53210/4162150908.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /tmp/ipykernel_53210/4162150908.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /tmp/ipykernel_53210/4162150908.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /tmp/ipykernel_53210/4162150908.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /tmp/ipykernel_53210/4162150908.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /tmp/ipykernel_53210/4162150908.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /tmp/ipykernel_53210/4162150908.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /tmp/ipykernel_53210/4162150908.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /tmp/ipykernel_53210/4162150908.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /tmp/ipykernel_53210/4162150908.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Year 2024-25 is finished.
#       PLAYER_NAME  Isolation_POSS_PCT  Isolation_EFG_PCT  Isolation_PTS  \
# 0    Aaron Gordon               0.057              0.636           18.0
# 1   Aaron Wiggins               0.035              0.300            8.0
# 2  Alexandre Sarr               0.036              0.179            8.0
# 3  Alperen Sengun               0.133              0.469           96.0
# 4   Amen Thompson               0.065              0.375           22.0
#
#    PRBallHandler_POSS_PCT  PRBallHandler_EFG_PCT  PRBallHandler_PTS  \
# 0                   0.097                  0.474               24.0
# 1                   0.078                  0.476               23.0
# 2                   0.000                  0.000                0.0
# 3                   0.043                  0.589               42.0
# 4                   0.138                  0.477               58.0
#
#    PRRollMan_POSS_PCT  PRRollMan_EFG_PCT  PRRollMan_PTS  ...  Cut_POSS_PCT  \
# 0               0.000              0.000            0.0  ...         0.150
# 1               0.056              0.528           23.0  ...         0.056
# 2               0.249              0.355           86.0  ...         0.105
# 3               0.204              0.496          155.0  ...         0.071
# 4               0.043              0.615           21.0  ...         0.151
#
#    Cut_EFG_PCT  Cut_PTS  OffScreen_POSS_PCT  OffScreen_EFG_PCT  OffScreen_PTS  \
# 0        0.767     58.0                 0.0                0.0            0.0
# 1        0.800     34.0                 0.0                0.0            0.0
# 2        0.622     65.0                 0.0                0.0            0.0
# 3        0.509     61.0                 0.0                0.0            0.0
# 4        0.680     88.0                 0.0                0.0            0.0
#
#    Misc_POSS_PCT  Misc_EFG_PCT  Misc_PTS   SEASON
# 0          0.053         0.500       6.0  2024-25
# 1          0.030         0.250       4.0  2024-25
# 2          0.066         0.286      14.0  2024-25
# 3          0.061         0.400      33.0  2024-25
# 4          0.052         0.500       5.0  2024-25
#
# [5 rows x 32 columns]
# 5    146
# 4     84
# 2     61
# 3     50
# 1     27
# Name: Cluster, dtype: int64
# Cluster 1 Summary:
# Isolation_POSS_PCT          0.089519
# Isolation_EFG_PCT           0.424259
# Isolation_PTS              60.370370
# PRBallHandler_POSS_PCT      0.097926
# PRBallHandler_EFG_PCT       0.452296
# PRBallHandler_PTS          61.666667
# PRRollMan_POSS_PCT          0.079000
# PRRollMan_EFG_PCT           0.520963
# PRRollMan_PTS              65.703704
# Spotup_POSS_PCT             0.210481
# Spotup_EFG_PCT              0.518519
# Spotup_PTS                135.518519
# Postup_POSS_PCT             0.116074
# Postup_EFG_PCT              0.502926
# Postup_PTS                 85.555556
# Transition_POSS_PCT         0.164852
# Transition_EFG_PCT          0.650741
# Transition_PTS            133.370370
# Handoff_POSS_PCT            0.029963
# Handoff_EFG_PCT             0.412741
# Handoff_PTS                17.444444
# Cut_POSS_PCT                0.067741
# Cut_EFG_PCT                 0.694148
# Cut_PTS                    64.555556
# OffScreen_POSS_PCT          0.035444
# OffScreen_EFG_PCT           0.388778
# OffScreen_PTS              25.185185
# Misc_POSS_PCT               0.049296
# Misc_EFG_PCT                0.474296
# Misc_PTS                   20.074074
# Name: 1, dtype: float64
# ----------------------------------------
# Cluster 2 Summary:
# Isolation_POSS_PCT          0.095869
# Isolation_EFG_PCT           0.445820
# Isolation_PTS              65.393443
# PRBallHandler_POSS_PCT      0.257836
# PRBallHandler_EFG_PCT       0.515246
# PRBallHandler_PTS         173.852459
# PRRollMan_POSS_PCT          0.010082
# PRRollMan_EFG_PCT           0.147213
# PRRollMan_PTS               6.196721
# Spotup_POSS_PCT             0.190475
# Spotup_EFG_PCT              0.571426
# Spotup_PTS                129.704918
# Postup_POSS_PCT             0.011295
# Postup_EFG_PCT              0.129148
# Postup_PTS                  8.360656
# Transition_POSS_PCT         0.190623
# Transition_EFG_PCT          0.599098
# Transition_PTS            140.704918
# Handoff_POSS_PCT            0.078852
# Handoff_EFG_PCT             0.525328
# Handoff_PTS                51.114754
# Cut_POSS_PCT                0.025508
# Cut_EFG_PCT                 0.427672
# Cut_PTS                    21.704918
# OffScreen_POSS_PCT          0.061492
# OffScreen_EFG_PCT           0.507934
# OffScreen_PTS              39.459016
# Misc_POSS_PCT               0.045344
# Misc_EFG_PCT                0.373344
# Misc_PTS                   17.819672
# Name: 2, dtype: float64
# ----------------------------------------
# Cluster 3 Summary:
# Isolation_POSS_PCT         0.01040
# Isolation_EFG_PCT          0.08332
# Isolation_PTS              3.32000
# PRBallHandler_POSS_PCT     0.00084
# PRBallHandler_EFG_PCT      0.01250
# PRBallHandler_PTS          0.22000
# PRRollMan_POSS_PCT         0.21606
# PRRollMan_EFG_PCT          0.60184
# PRRollMan_PTS             75.52000
# Spotup_POSS_PCT            0.09264
# Spotup_EFG_PCT             0.29876
# Spotup_PTS                28.76000
# Postup_POSS_PCT            0.07062
# Postup_EFG_PCT             0.39586
# Postup_PTS                27.92000
# Transition_POSS_PCT        0.11148
# Transition_EFG_PCT         0.68410
# Transition_PTS            39.96000
# Handoff_POSS_PCT           0.00070
# Handoff_EFG_PCT            0.01286
# Handoff_PTS                0.30000
# Cut_POSS_PCT               0.21066
# Cut_EFG_PCT                0.65748
# Cut_PTS                   73.52000
# OffScreen_POSS_PCT         0.00170
# OffScreen_EFG_PCT          0.02320
# OffScreen_PTS              0.90000
# Misc_POSS_PCT              0.09282
# Misc_EFG_PCT               0.47498
# Misc_PTS                   9.54000
# Name: 3, dtype: float64
# ----------------------------------------
# Cluster 4 Summary:
# Isolation_POSS_PCT         0.046893
# Isolation_EFG_PCT          0.242202
# Isolation_PTS             15.357143
# PRBallHandler_POSS_PCT     0.195619
# PRBallHandler_EFG_PCT      0.422083
# PRBallHandler_PTS         55.214286
# PRRollMan_POSS_PCT         0.016036
# PRRollMan_EFG_PCT          0.221905
# PRRollMan_PTS              7.261905
# Spotup_POSS_PCT            0.263012
# Spotup_EFG_PCT             0.533631
# Spotup_PTS                82.750000
# Postup_POSS_PCT            0.013083
# Postup_EFG_PCT             0.072298
# Postup_PTS                 3.738095
# Transition_POSS_PCT        0.192452
# Transition_EFG_PCT         0.569190
# Transition_PTS            65.380952
# Handoff_POSS_PCT           0.074917
# Handoff_EFG_PCT            0.437988
# Handoff_PTS               20.666667
# Cut_POSS_PCT               0.027381
# Cut_EFG_PCT                0.258119
# Cut_PTS                   13.166667
# OffScreen_POSS_PCT         0.042762
# OffScreen_EFG_PCT          0.217238
# OffScreen_PTS             10.761905
# Misc_POSS_PCT              0.034917
# Misc_EFG_PCT               0.182155
# Misc_PTS                   5.321429
# Name: 4, dtype: float64
# ----------------------------------------
# Cluster 5 Summary:
# Isolation_POSS_PCT         0.016596
# Isolation_EFG_PCT          0.089500
# Isolation_PTS              4.075342
# PRBallHandler_POSS_PCT     0.082226
# PRBallHandler_EFG_PCT      0.246171
# PRBallHandler_PTS         15.883562
# PRRollMan_POSS_PCT         0.041979
# PRRollMan_EFG_PCT          0.226082
# PRRollMan_PTS              9.246575
# Spotup_POSS_PCT            0.334432
# Spotup_EFG_PCT             0.498651
# Spotup_PTS                78.986301
# Postup_POSS_PCT            0.004322
# Postup_EFG_PCT             0.025219
# Postup_PTS                 0.952055
# Transition_POSS_PCT        0.202425
# Transition_EFG_PCT         0.541021
# Transition_PTS            55.157534
# Handoff_POSS_PCT           0.013925
# Handoff_EFG_PCT            0.105500
# Handoff_PTS                3.760274
# Cut_POSS_PCT               0.065116
# Cut_EFG_PCT                0.403116
# Cut_PTS                   19.506849
# OffScreen_POSS_PCT         0.005623
# OffScreen_EFG_PCT          0.044192
# OffScreen_PTS              1.506849
# Misc_POSS_PCT              0.040897
# Misc_EFG_PCT               0.260110
# Misc_PTS                   4.650685
# Name: 5, dtype: float64
# ----------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 183
#     178 pca = PCA(n_components=0.99)
#     182 principalComponents = pca.fit_transform(x)
# --> 183 Print('EXPLAIN SECTION')
#     185 explained_variance_ratio = pca.explained_variance_ratio_
#     186 cumulative_variance = explained_variance_ratio.cumsum()
#
# NameError: name 'Print' is not defined
