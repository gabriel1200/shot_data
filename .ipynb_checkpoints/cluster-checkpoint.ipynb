# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import pandas as pd
import numpy as np
import unidecode
import requests
import time


from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


from scipy.cluster.hierarchy import fcluster
from scipy.cluster.hierarchy import linkage
import pandas as pd

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import numpy as np


import plotly.express as px
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

headers = {
    'Host': 'stats.nba.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br',
    'x-nba-stats-origin': 'stats',
    'x-nba-stats-token': 'true',
    'Connection': 'keep-alive',
    'Referer': 'https://stats.nba.com/',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache'
}

df_list = []

for ssn in ['2024-25']:

    # Synergy Playtypes
    playtypes = [
        'Isolation', 'PRBallHandler', 'PRRollMan', 'Spotup', 'Postup', 'Transition', 'Handoff', 'Cut', 'OffScreen', 'Misc'
    ]

    synergy_data = []

    for playtype in playtypes:
        url = f'https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=Totals&PlayType={playtype}&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear={ssn}&TypeGrouping=offensive'
        response = requests.get(url, headers=headers).json()
        time.sleep(1)

        data = response['resultSets'][0]['rowSet']
        columns = response['resultSets'][0]['headers']

        df = pd.DataFrame.from_records(data, columns=columns)

        # Rename columns for clarity
        df.rename(columns={
            'POSS_PCT': f'{playtype}_POSS_PCT',
            'EFG_PCT': f'{playtype}_EFG_PCT',
            'PTS': f'{playtype}_PTS'
        }, inplace=True)

        # Weighted averages and summing points
        g = df.groupby(['PLAYER_NAME'])
        df = pd.merge(
            g.apply(lambda x: pd.Series(
                np.average(x[[f'{playtype}_POSS_PCT', f'{playtype}_EFG_PCT']], weights=x['POSS'], axis=0),
                [f'{playtype}_POSS_PCT', f'{playtype}_EFG_PCT']
            )).reset_index(drop=False),
            pd.DataFrame(g.sum()[f'{playtype}_PTS']).reset_index(drop=False),
            on='PLAYER_NAME'
        )

        synergy_data.append(df)

    # Merge all synergy playtype data
    synergy_df = synergy_data[0]
    for df in synergy_data[1:]:
        synergy_df = pd.merge(synergy_df, df, on='PLAYER_NAME', how='outer')

    synergy_df.fillna(0, inplace=True)
    synergy_df['SEASON'] = ssn

    df_list.append(synergy_df)
    print(f"Year {ssn} is finished.")

# Combine all seasons
df = pd.concat(df_list).reset_index(drop=True)

# Preview the data
print(df.head())


# In[3]:


#testdf = df[(df.MPG > 23) & (df.GP > 15) & (df.SEASON == '2022-23')].reset_index(drop=True)
testdf = df.reset_index(drop=True)

features = [x for x in df.columns if (x != 'PLAYER_NAME') &  (x != 'POSITION') & (x != 'SEASON')]

x = testdf.loc[:, features].values
y = testdf.loc[:,['PLAYER_NAME']].values

x = StandardScaler().fit_transform(x) # standardize all values

pca = PCA(n_components=0.99)
principalComponents = pca.fit_transform(x)

plt.figure(figsize=(10,65))
plt.title('2024-25 NBA Hierarchical Clustering Dendrogram')
dend = shc.dendrogram(shc.linkage(x, method='ward'), labels=list(testdf.PLAYER_NAME), orientation='left')

plt.yticks(fontsize=8)
plt.xlabel('Height')

plt.tight_layout()

# Save the plot in PNG format
plt.savefig("nba_hierarchical_clustering_dendrogram.png", format='png', dpi=300)

# Optionally, display the plot as well
plt.show()


# In[11]:

# Compute linkage matrix (using Ward's method as in your dendrogram)
linkage_matrix = shc.linkage(x, method='ward')

# Set a distance threshold (adjust based on your dendrogram)
distance_threshold = 30  # Adjust based on large vertical gaps in the dendrogram

# Find clusters
clusters = fcluster(linkage_matrix, distance_threshold, criterion='distance')

# Add cluster labels to the dataframe
testdf['Cluster'] = clusters

# Print cluster counts
print(testdf['Cluster'].value_counts())

# Save the cluster assignments
testdf[['PLAYER_NAME', 'Cluster']].to_csv('nba_hierarchical_clusters.csv', index=False)

# Exclude non-numeric columns for the cluster summary
numeric_features = testdf.select_dtypes(include=[np.number])  # Keep only numeric columns
numeric_features['Cluster'] = testdf['Cluster']  # Add Cluster column back

# Calculate the mean for each numeric feature grouped by Cluster
cluster_summary = numeric_features.groupby('Cluster').mean()

# Print the feature summary for each cluster
for cluster_id in cluster_summary.index:
    print(f"Cluster {cluster_id} Summary:")
    print(cluster_summary.loc[cluster_id])
    print("-" * 40)

# Optionally, save the cluster summary to a CSV
cluster_summary.to_csv('nba_hierarchical_cluster_summary.csv', index=True)


# In[16]:



# Use the processed data after PCA
x = testdf.loc[:, features].values
x = StandardScaler().fit_transform(x)
pca = PCA(n_components=0.99)
principalComponents = pca.fit_transform(x)

# Determine optimal number of clusters using the elbow method
inertia = []
silhouette_scores = []
k_values = range(2, 30)  # Testing for 2 to 10 clusters

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10, max_iter=500)
    kmeans.fit(principalComponents)
    inertia.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(principalComponents, kmeans.labels_))
# Choose the optimal number of clusters (e.g., based on plots)
optimal_k = 13  # Replace with the chosen k based on visual inspection

# Fit K-Means with the optimal number of clusters
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10, max_iter=500)
kmeans.fit(principalComponents)

# Add cluster labels to the dataframe
testdf['Cluster'] = kmeans.labels_
# Add rank within each cluster based on a metric (e.g., PCA1 or a scoring column)
testdf['RankInCluster'] = (
    testdf.groupby('Cluster')['PCA1']  # Replace 'PCA1' with your preferred metric
    .rank(method='dense', ascending=False)
)

# Optionally, normalize the rank to a scale of 0-1 for better visualization
testdf['NormalizedRank'] = (
    testdf.groupby('Cluster')['RankInCluster']
    .transform(lambda x: (x - x.min()) / (x.max() - x.min()))
)

# Save results to a CSV (optional)
testdf[['PLAYER_NAME', 'Cluster','RankInCluster','NormalizedRank']].to_csv('nba_kmeans_clusters.csv', index=False)


# Use the processed data
x = testdf.loc[:, features].values
x = StandardScaler().fit_transform(x)
pca = PCA(n_components=0.99)
principalComponents = pca.fit_transform(x)

# Choose the optimal number of clusters
optimal_k = 13
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10, max_iter=500)
kmeans.fit(principalComponents)

# Add cluster labels and PCA components to the dataframe
testdf['Cluster'] = kmeans.labels_
testdf['PCA1'] = principalComponents[:, 0]  # First principal component
testdf['PCA2'] = principalComponents[:, 1]  # Second principal component
# Exclude non-numeric columns for the feature summary
numeric_features = testdf.select_dtypes(include=[np.number])

# Add the Cluster column back to the numeric_features dataframe
numeric_features['Cluster'] = testdf['Cluster']

# Calculate the mean for each numeric feature grouped by Cluster
feature_summary = numeric_features.groupby('Cluster').mean()

# Print the feature summary for each cluster
for cluster_id in range(optimal_k):
    print(f"Cluster {cluster_id} Summary:")
    print(feature_summary.loc[cluster_id])
    print("-" * 40)

# Optionally, save the feature summary to a CSV
feature_summary.to_csv('cluster_feature_summary.csv', index=True)
# Visualize the clusters in the first two PCA components
# Plotting the Elbow Method
plt.figure(figsize=(10, 5))
plt.plot(k_values, inertia, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# Plotting Silhouette Scores
plt.figure(figsize=(10, 5))
plt.plot(k_values, silhouette_scores, marker='o', color='green')
plt.title('Silhouette Scores for Different k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.grid()
plt.show()



plt.figure(figsize=(10, 7))
for cluster in range(optimal_k):
    cluster_points = principalComponents[kmeans.labels_ == cluster]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {cluster}')

plt.title('K-Means Clustering Visualization')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend()
plt.grid()
plt.show()


# In[20]:


# Define consistent color mapping for clusters
color_map = px.colors.qualitative.Set1  # Adjust this if more than 10 clusters
cluster_colors = {cluster: color_map[i % len(color_map)] for i, cluster in enumerate(sorted(testdf['Cluster'].unique()))}

# Create the base scatter plot
fig = px.scatter(
    testdf,
    x='PCA1',
    y='PCA2',
    color='Cluster',
    color_discrete_map=cluster_colors,
    hover_data=['PLAYER_NAME'],  # Show player names on hover
    title='K-Means Clustering Visualization',
    labels={'PCA1': 'Principal Component 1', 'PCA2': 'Principal Component 2'},
)

# Add a dropdown menu to filter clusters
fig.update_layout(
    updatemenus=[
        {
            "buttons": [
                {
                    "label": f"Show Cluster {cluster}",
                    "method": "update",
                    "args": [
                        {
                            "marker": {"opacity": [1 if c == cluster else 0.2 for c in testdf['Cluster']]},
                        },
                        {"title": f"K-Means Clustering: Cluster {cluster} Highlighted"},
                    ],
                }
                for cluster in sorted(testdf['Cluster'].unique())
            ]
            + [
                {
                    "label": "Show All Clusters",
                    "method": "update",
                    "args": [
                        {
                            "marker": {"opacity": [1 for _ in testdf['Cluster']]},
                        },
                        {"title": "K-Means Clustering: All Clusters"},
                    ],
                }
            ],
            "direction": "down",
            "showactive": True,
        }
    ]
)

# Show the plot
fig.show()


# In[17]:
# Out:
# /tmp/ipykernel_106496/2372217055.py:62: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(g.sum()[f'{playtype}_PTS']).reset_index(drop=False),
# /tmp/ipykernel_106496/2372217055.py:62: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(g.sum()[f'{playtype}_PTS']).reset_index(drop=False),
# /tmp/ipykernel_106496/2372217055.py:62: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(g.sum()[f'{playtype}_PTS']).reset_index(drop=False),
# /tmp/ipykernel_106496/2372217055.py:62: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(g.sum()[f'{playtype}_PTS']).reset_index(drop=False),
# /tmp/ipykernel_106496/2372217055.py:62: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(g.sum()[f'{playtype}_PTS']).reset_index(drop=False),
# /tmp/ipykernel_106496/2372217055.py:62: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(g.sum()[f'{playtype}_PTS']).reset_index(drop=False),
# /tmp/ipykernel_106496/2372217055.py:62: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(g.sum()[f'{playtype}_PTS']).reset_index(drop=False),
# /tmp/ipykernel_106496/2372217055.py:62: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(g.sum()[f'{playtype}_PTS']).reset_index(drop=False),
# /tmp/ipykernel_106496/2372217055.py:62: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(g.sum()[f'{playtype}_PTS']).reset_index(drop=False),
# /tmp/ipykernel_106496/2372217055.py:62: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(g.sum()[f'{playtype}_PTS']).reset_index(drop=False),
# Year 2024-25 is finished.
#       PLAYER_NAME  Isolation_POSS_PCT  Isolation_EFG_PCT  Isolation_PTS  \
# 0    Aaron Gordon               0.047              0.750           14.0
# 1   Aaron Wiggins               0.030              0.250            6.0
# 2  Alexandre Sarr               0.037              0.179            7.0
# 3  Alperen Sengun               0.141              0.481           94.0
# 4   Amen Thompson               0.068              0.391           22.0
#
#    PRBallHandler_POSS_PCT  PRBallHandler_EFG_PCT  PRBallHandler_PTS  \
# 0                   0.084                  0.393               16.0
# 1                   0.069                  0.500               19.0
# 2                   0.000                  0.000                0.0
# 3                   0.041                  0.583               37.0
# 4                   0.140                  0.439               52.0
#
#    PRRollMan_POSS_PCT  PRRollMan_EFG_PCT  PRRollMan_PTS  ...  Cut_POSS_PCT  \
# 0               0.000              0.000            0.0  ...         0.163
# 1               0.054              0.531           21.0  ...         0.054
# 2               0.248              0.366           80.0  ...         0.105
# 3               0.203              0.492          142.0  ...         0.071
# 4               0.041              0.615           20.0  ...         0.155
#
#    Cut_EFG_PCT  Cut_PTS  OffScreen_POSS_PCT  OffScreen_EFG_PCT  OffScreen_PTS  \
# 0        0.759     54.0                 0.0                0.0            0.0
# 1        0.765     28.0                 0.0                0.0            0.0
# 2        0.619     61.0                 0.0                0.0            0.0
# 3        0.510     56.0                 0.0                0.0            0.0
# 4        0.660     82.0                 0.0                0.0            0.0
#
#    Misc_POSS_PCT  Misc_EFG_PCT  Misc_PTS   SEASON
# 0          0.051         0.500       6.0  2024-25
# 1          0.000         0.000       0.0  2024-25
# 2          0.070         0.333      14.0  2024-25
# 3          0.065         0.400      33.0  2024-25
# 4          0.051         0.500       5.0  2024-25
#
# [5 rows x 32 columns]
# 2    125
# 4     73
# 1     57
# 5     54
# 6     40
# 3     16
# Name: Cluster, dtype: int64
# Cluster 1 Summary:
# Isolation_POSS_PCT         0.029825
# Isolation_EFG_PCT          0.152175
# Isolation_PTS             17.228070
# PRBallHandler_POSS_PCT     0.012386
# PRBallHandler_EFG_PCT      0.109930
# PRBallHandler_PTS          8.666667
# PRRollMan_POSS_PCT         0.196614
# PRRollMan_EFG_PCT          0.590263
# PRRollMan_PTS             81.403509
# Spotup_POSS_PCT            0.115158
# Spotup_EFG_PCT             0.330070
# Spotup_PTS                49.438596
# Postup_POSS_PCT            0.096193
# Postup_EFG_PCT             0.480526
# Postup_PTS                47.192982
# Transition_POSS_PCT        0.118175
# Transition_EFG_PCT         0.653807
# Transition_PTS            58.368421
# Handoff_POSS_PCT           0.002667
# Handoff_EFG_PCT            0.064316
# Handoff_PTS                1.807018
# Cut_POSS_PCT               0.174158
# Cut_EFG_PCT                0.672860
# Cut_PTS                   75.333333
# OffScreen_POSS_PCT         0.006789
# OffScreen_EFG_PCT          0.091912
# OffScreen_PTS              4.964912
# Misc_POSS_PCT              0.086439
# Misc_EFG_PCT               0.488474
# Misc_PTS                  12.964912
# Name: 1, dtype: float64
# ----------------------------------------
# Cluster 2 Summary:
# Isolation_POSS_PCT         0.041560
# Isolation_EFG_PCT          0.203536
# Isolation_PTS             11.280000
# PRBallHandler_POSS_PCT     0.175088
# PRBallHandler_EFG_PCT      0.378112
# PRBallHandler_PTS         38.496000
# PRRollMan_POSS_PCT         0.002216
# PRRollMan_EFG_PCT          0.022064
# PRRollMan_PTS              0.552000
# Spotup_POSS_PCT            0.293504
# Spotup_EFG_PCT             0.525000
# Spotup_PTS                63.408000
# Postup_POSS_PCT            0.008008
# Postup_EFG_PCT             0.048288
# Postup_PTS                 2.040000
# Transition_POSS_PCT        0.211824
# Transition_EFG_PCT         0.568832
# Transition_PTS            48.584000
# Handoff_POSS_PCT           0.036440
# Handoff_EFG_PCT            0.254592
# Handoff_PTS                8.848000
# Cut_POSS_PCT               0.022720
# Cut_EFG_PCT                0.200264
# Cut_PTS                    7.656000
# OffScreen_POSS_PCT         0.007760
# OffScreen_EFG_PCT          0.036912
# OffScreen_PTS              2.000000
# Misc_POSS_PCT              0.032768
# Misc_EFG_PCT               0.135552
# Misc_PTS                   3.808000
# Name: 2, dtype: float64
# ----------------------------------------
# Cluster 3 Summary:
# Isolation_POSS_PCT         0.000000
# Isolation_EFG_PCT          0.000000
# Isolation_PTS              0.000000
# PRBallHandler_POSS_PCT     0.035125
# PRBallHandler_EFG_PCT      0.025250
# PRBallHandler_PTS          1.312500
# PRRollMan_POSS_PCT         0.126062
# PRRollMan_EFG_PCT          0.322688
# PRRollMan_PTS             10.375000
# Spotup_POSS_PCT            0.152375
# Spotup_EFG_PCT             0.207125
# Spotup_PTS                11.625000
# Postup_POSS_PCT            0.009500
# Postup_EFG_PCT             0.008937
# Postup_PTS                 0.250000
# Transition_POSS_PCT        0.007687
# Transition_EFG_PCT         0.031250
# Transition_PTS             0.937500
# Handoff_POSS_PCT           0.000000
# Handoff_EFG_PCT            0.000000
# Handoff_PTS                0.000000
# Cut_POSS_PCT               0.177937
# Cut_EFG_PCT                0.408562
# Cut_PTS                   20.812500
# OffScreen_POSS_PCT         0.000000
# OffScreen_EFG_PCT          0.000000
# OffScreen_PTS              0.000000
# Misc_POSS_PCT              0.038812
# Misc_EFG_PCT               0.000000
# Misc_PTS                   0.687500
# Name: 3, dtype: float64
# ----------------------------------------
# Cluster 4 Summary:
# Isolation_POSS_PCT          0.016356
# Isolation_EFG_PCT           0.137425
# Isolation_PTS               5.178082
# PRBallHandler_POSS_PCT      0.045534
# PRBallHandler_EFG_PCT       0.215521
# PRBallHandler_PTS          14.109589
# PRRollMan_POSS_PCT          0.076973
# PRRollMan_EFG_PCT           0.498356
# PRRollMan_PTS              21.013699
# Spotup_POSS_PCT             0.342630
# Spotup_EFG_PCT              0.517863
# Spotup_PTS                106.520548
# Postup_POSS_PCT             0.014671
# Postup_EFG_PCT              0.091397
# Postup_PTS                  5.890411
# Transition_POSS_PCT         0.207918
# Transition_EFG_PCT          0.628123
# Transition_PTS             74.520548
# Handoff_POSS_PCT            0.014986
# Handoff_EFG_PCT             0.138329
# Handoff_PTS                 5.232877
# Cut_POSS_PCT                0.088041
# Cut_EFG_PCT                 0.566781
# Cut_PTS                    32.041096
# OffScreen_POSS_PCT          0.014644
# OffScreen_EFG_PCT           0.121630
# OffScreen_PTS               5.191781
# Misc_POSS_PCT               0.052082
# Misc_EFG_PCT                0.429315
# Misc_PTS                    7.246575
# Name: 4, dtype: float64
# ----------------------------------------
# Cluster 5 Summary:
# Isolation_POSS_PCT          0.113519
# Isolation_EFG_PCT           0.450593
# Isolation_PTS              74.574074
# PRBallHandler_POSS_PCT      0.286630
# PRBallHandler_EFG_PCT       0.507741
# PRBallHandler_PTS         183.870370
# PRRollMan_POSS_PCT          0.010000
# PRRollMan_EFG_PCT           0.170907
# PRRollMan_PTS               6.555556
# Spotup_POSS_PCT             0.165315
# Spotup_EFG_PCT              0.551407
# Spotup_PTS                110.740741
# Postup_POSS_PCT             0.023648
# Postup_EFG_PCT              0.181389
# Postup_PTS                 16.518519
# Transition_POSS_PCT         0.188444
# Transition_EFG_PCT          0.602185
# Transition_PTS            137.092593
# Handoff_POSS_PCT            0.071630
# Handoff_EFG_PCT             0.518926
# Handoff_PTS                44.851852
# Cut_POSS_PCT                0.027556
# Cut_EFG_PCT                 0.469037
# Cut_PTS                    22.851852
# OffScreen_POSS_PCT          0.039241
# OffScreen_EFG_PCT           0.495500
# OffScreen_PTS              25.370370
# Misc_POSS_PCT               0.045500
# Misc_EFG_PCT                0.369370
# Misc_PTS                   17.462963
# Name: 5, dtype: float64
# ----------------------------------------
# Cluster 6 Summary:
# Isolation_POSS_PCT          0.012375
# Isolation_EFG_PCT           0.118450
# Isolation_PTS               5.800000
# PRBallHandler_POSS_PCT      0.105400
# PRBallHandler_EFG_PCT       0.403975
# PRBallHandler_PTS          37.950000
# PRRollMan_POSS_PCT          0.025550
# PRRollMan_EFG_PCT           0.295950
# PRRollMan_PTS              11.150000
# Spotup_POSS_PCT             0.303800
# Spotup_EFG_PCT              0.565100
# Spotup_PTS                112.825000
# Postup_POSS_PCT             0.001050
# Postup_EFG_PCT              0.008825
# Postup_PTS                  0.575000
# Transition_POSS_PCT         0.204750
# Transition_EFG_PCT          0.591900
# Transition_PTS             83.625000
# Handoff_POSS_PCT            0.100025
# Handoff_EFG_PCT             0.447775
# Handoff_PTS                35.500000
# Cut_POSS_PCT                0.033325
# Cut_EFG_PCT                 0.367650
# Cut_PTS                    16.725000
# OffScreen_POSS_PCT          0.111200
# OffScreen_EFG_PCT           0.499150
# OffScreen_PTS              41.325000
# Misc_POSS_PCT               0.025775
# Misc_EFG_PCT                0.249750
# Misc_PTS                    6.850000
# Name: 6, dtype: float64
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 202
#     199 testdf['Cluster'] = kmeans.labels_
#     200 # Add rank within each cluster based on a metric (e.g., PCA1 or a scoring column)
#     201 testdf['RankInCluster'] = (
# --> 202     testdf.groupby('Cluster')['PCA1']  # Replace 'PCA1' with your preferred metric
#     203     .rank(method='dense', ascending=False)
#     204 )
#     206 # Optionally, normalize the rank to a scale of 0-1 for better visualization
#     207 testdf['NormalizedRank'] = (
#     208     testdf.groupby('Cluster')['RankInCluster']
#     209     .transform(lambda x: (x - x.min()) / (x.max() - x.min()))
#     210 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/generic.py:1416, in DataFrameGroupBy.__getitem__(self, key)
#    1407 if isinstance(key, tuple) and len(key) > 1:
#    1408     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1409     # valid syntax, so don't raise warning
#    1410     warnings.warn(
#    1411         "Indexing with multiple keys (implicitly converted to a tuple "
#    1412         "of keys) will be deprecated, use a list instead.",
#    1413         FutureWarning,
#    1414         stacklevel=find_stack_level(),
#    1415     )
# -> 1416 return super().__getitem__(key)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/base.py:248, in SelectionMixin.__getitem__(self, key)
#     246 else:
#     247     if key not in self.obj:
# --> 248         raise KeyError(f"Column not found: {key}")
#     249     subset = self.obj[key]
#     250     ndim = subset.ndim
#
# KeyError: 'Column not found: PCA1'
