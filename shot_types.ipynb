# %%
import pandas as pd
import os
import numpy as np
def get_shot_categories_and_mapping():
    # Updated shot categories with separated 2PT and 3PT jump shots
    shot_categories = {
        'TWO_POINT_JUMPERS': [
            '2PT Jump Shot',
            '2PT Pullup Jump Shot',
            '2PT Step Back Jump Shot',
            '2PT Fadeaway Jump Shot',
            '2PT Running Jump Shot',
            '2PT Turnaround Jump Shot',
            '2PT Driving Jump Shot'
        ],
        
        'THREE_POINT_JUMPERS': [
            '3PT Jump Shot',
            '3PT Pullup Jump Shot',
            '3PT Step Back Jump Shot',
            '3PT Fadeaway Jump Shot',
            '3PT Running Jump Shot',
            '3PT Turnaround Jump Shot',
            '3PT Driving Jump Shot'
        ],
        
        'LAYUPS': [
            'Standard Layup',
            'Driving Layup',
            'Finger Roll',
            'Reverse Layup',
            'Putback Layup',
            'Alley Oop Layup'
        ],
        
        'DUNKS': [
            'Standard Dunk',
            'Driving Dunk',
            'Reverse Dunk',
            'Putback Dunk',
            'Alley Oop Dunk',
            'Specialty Dunk'
        ],
        
        'POST_MOVES': [
            'Hook Shot',
            'Running Hook Shot',
            'Turnaround Hook Shot',
            'Driving Hook Shot'
        ],
        
        'FLOATING_SHOTS': [
            '2PT Floating Jump Shot',
            '3PT Floating Jump Shot'
        ],
        
        'TIP_SHOTS': [
            'Tip Shot'
        ],
        
        'NO_SHOT': ['No Shot']
    }
    
    # Updated mapping to include shot type distinction
    shot_mapping = {
        # 2PT Jump Shots
        'Jump Shot': lambda x: '3PT Jump Shot' if x == '3' else '2PT Jump Shot',
        'Pullup Jump shot': lambda x: '3PT Pullup Jump Shot' if x == '3' else '2PT Pullup Jump Shot',
        'Pullup Bank shot': lambda x: '3PT Pullup Jump Shot' if x == '3' else '2PT Pullup Jump Shot',
        'Step Back Jump shot': lambda x: '3PT Step Back Jump Shot' if x == '3' else '2PT Step Back Jump Shot',
        'Step Back Bank Jump Shot': lambda x: '3PT Step Back Jump Shot' if x == '3' else '2PT Step Back Jump Shot',
        'Fadeaway Jump Shot': lambda x: '3PT Fadeaway Jump Shot' if x == '3' else '2PT Fadeaway Jump Shot',
        'Fadeaway Bank shot': lambda x: '3PT Fadeaway Jump Shot' if x == '3' else '2PT Fadeaway Jump Shot',
        'Running Jump Shot': lambda x: '3PT Running Jump Shot' if x == '3' else '2PT Running Jump Shot',
        'Running Pull-Up Jump Shot': lambda x: '3PT Running Jump Shot' if x == '3' else '2PT Running Jump Shot',
        'Running Bank shot': lambda x: '3PT Running Jump Shot' if x == '3' else '2PT Running Jump Shot',
        'Jump Bank Shot': lambda x: '3PT Jump Shot' if x == '3' else '2PT Jump Shot',
        'Turnaround Jump Shot': lambda x: '3PT Turnaround Jump Shot' if x == '3' else '2PT Turnaround Jump Shot',
        'Turnaround Fadeaway shot': lambda x: '3PT Turnaround Jump Shot' if x == '3' else '2PT Turnaround Jump Shot',
        'Turnaround Bank shot': lambda x: '3PT Turnaround Jump Shot' if x == '3' else '2PT Turnaround Jump Shot',
        'Turnaround Fadeaway Bank Jump Shot': lambda x: '3PT Turnaround Jump Shot' if x == '3' else '2PT Turnaround Jump Shot',
        'Driving Jump shot': lambda x: '3PT Driving Jump Shot' if x == '3' else '2PT Driving Jump Shot',
        'Driving Bank shot': lambda x: '3PT Driving Jump Shot' if x == '3' else '2PT Driving Jump Shot',
        'Floating Jump shot': lambda x: '3PT Floating Jump Shot' if x == '3' else '2PT Floating Jump Shot',
        'Driving Floating Jump Shot': lambda x: '3PT Floating Jump Shot' if x == '3' else '2PT Floating Jump Shot',
        'Driving Floating Bank Jump Shot': lambda x: '3PT Floating Jump Shot' if x == '3' else '2PT Floating Jump Shot',
        
        # Non-jump shots (remain the same regardless of shot type)
        'Layup Shot': 'Standard Layup',
        'Running Layup Shot': 'Standard Layup',
        'Cutting Layup Shot': 'Standard Layup',
        'Driving Layup Shot': 'Driving Layup',
        'Driving Reverse Layup Shot': 'Driving Layup',
        'Reverse Layup Shot': 'Reverse Layup',
        'Running Reverse Layup Shot': 'Reverse Layup',
        'Tip Layup Shot': 'Putback Layup',
        'Putback Layup Shot': 'Putback Layup',
        'Alley Oop Layup shot': 'Alley Oop Layup',
        'Running Alley Oop Layup Shot': 'Alley Oop Layup',
        'Driving Finger Roll Layup Shot': 'Finger Roll',
        'Finger Roll Layup Shot': 'Finger Roll',
        'Running Finger Roll Layup Shot': 'Finger Roll',
        'Cutting Finger Roll Layup Shot': 'Finger Roll',
        'Finger Roll Shot': 'Finger Roll',
        'Running Finger Roll Shot': 'Finger Roll',
        'Turnaround Finger Roll Shot': 'Finger Roll',
        'Driving Finger Roll Shot': 'Finger Roll',
        'Dunk Shot': 'Standard Dunk',
        'Slam Dunk Shot': 'Standard Dunk',
        'Running Dunk Shot': 'Standard Dunk',
        'Running Slam Dunk Shot': 'Standard Dunk',
        'Driving Dunk Shot': 'Driving Dunk',
        'Driving Slam Dunk Shot': 'Driving Dunk',
        'Driving Reverse Dunk Shot': 'Reverse Dunk',
        'Reverse Dunk Shot': 'Reverse Dunk',
        'Reverse Slam Dunk Shot': 'Reverse Dunk',
        'Running Reverse Dunk Shot': 'Reverse Dunk',
        'Putback Dunk Shot': 'Putback Dunk',
        'Putback Reverse Dunk Shot': 'Putback Dunk',
        'Putback Slam Dunk Shot': 'Putback Dunk',
        'Alley Oop Dunk Shot': 'Alley Oop Dunk',
        'Running Alley Oop Dunk Shot': 'Alley Oop Dunk',
        'Cutting Dunk Shot': 'Specialty Dunk',
        'Tip Dunk Shot': 'Specialty Dunk',
        'Follow Up Dunk Shot': 'Specialty Dunk',
        'Hook Shot': 'Hook Shot',
        'Jump Hook Shot': 'Hook Shot',
        'Running Hook Shot': 'Running Hook Shot',
        'Running Bank Hook Shot': 'Running Hook Shot',
        'Turnaround Hook Shot': 'Turnaround Hook Shot',
        'Turnaround Bank Hook Shot': 'Turnaround Hook Shot',
        'Driving Hook Shot': 'Driving Hook Shot',
        'Driving Bank Hook Shot': 'Driving Hook Shot',
        'Hook Bank Shot': 'Hook Shot',
        'Jump Bank Hook Shot': 'Hook Shot',
        'Tip Shot': 'Tip Shot',
        'Running Tip Shot': 'Tip Shot',
        'No Shot': 'No Shot'
    }
    
    return shot_categories, shot_mapping

def collect_year(year):
    path = 'team/'+str(year)+'/'
    arr = os.listdir(path)
    csvs = [file for file in arr if '.csv' in file and file !='avg.csv']
    frames= []
    for csv in csvs:
        df=pd.read_csv(path+csv)
        frames.append(df)
    master = pd.concat(frames)
    return master

def collect_types():
    shot_categories, mapping = get_shot_categories_and_mapping()
    category_map = {}
    
    # Build category mapping dictionary
    for shot_type, shotlist in shot_categories.items():
        for shot in shotlist:
            category_map[shot] = shot_type

    all_types = []
    
    for year in range(1997, 2026):
        df = collect_year(year)

        threes = ['24+ ft.', 'Back Court Shot']


        df['SHOT_TYPE'] = df['SHOT_ZONE_RANGE'].apply(lambda x:'3PT Field Goal' if x in threes else '2PT Field Goal')

        #df['SHOT_TYPE'].fillna('2PT Field Goal',inplace=True)
     

        value_map = {'2PT Field Goal': '2', '3PT Field Goal': '3'}
        if year>2004:
            print(df[df.PLAYER_ID==2544]['SHOT_TYPE'].value_counts())
        
            print(f" 3Pt Shots before mapping for player 2544: {df[(df.PLAYER_ID==2544)&(df.SHOT_TYPE.str.contains('3P'))]['SHOT_ATTEMPTED_FLAG'].sum()}")
        df['SHOT_TYPE'] = df['SHOT_TYPE'].map(value_map)

        df['shot_description'] = df.apply(
            lambda row: mapping[row['ACTION_TYPE']](row['SHOT_TYPE']) 
            if callable(mapping[row['ACTION_TYPE']]) 
            else mapping[row['ACTION_TYPE']], 
            axis=1
        )

        
        df['SHOT_ATTEMPTED_FLAG'] = df['SHOT_ATTEMPTED_FLAG'].astype(int)
        df['SHOT_MADE_FLAG'] = df['SHOT_MADE_FLAG'].astype(int)
        
        # Convert shot type to '2' or '3'
        df['SHOT_TYPE'] = np.where(df['SHOT_TYPE'].str.contains('3pt', case=False, na=False), '3', '2')
        
        # Create player breakdown
        player_breakdown = (
            df.groupby(['PLAYER_NAME', 'PLAYER_ID', 'shot_description'])
            .agg(
                shot_count=('SHOT_ATTEMPTED_FLAG', 'sum'),
                shot_makes=('SHOT_MADE_FLAG', 'sum'),
            )
            .reset_index()
        )
        
        # Apply the mapping with shot type consideration

        # Debug unique values before mapping
        print("\nUnique shot descriptions before mapping:")
        print(player_breakdown['shot_description'].unique())
        
        # Apply mappings and check for missing values
        #player_breakdown['old_description'] = player_breakdown['shot_description']
       
        
        # Debug missing mappings
        missing_mappings = player_breakdown[player_breakdown['shot_description'].isna()]
        if not missing_mappings.empty:
            print("\nMissing mappings found for:")
            print(missing_mappings['old_description'].unique())
        
        # Apply category mapping
        player_breakdown['shot_group'] = player_breakdown['shot_description'].map(category_map)
        
        # Debug category mapping
        missing_categories = player_breakdown[player_breakdown['shot_group'].isna()]
        if not missing_categories.empty:
            print("\nMissing categories found for:")
            print(missing_categories['shot_description'].unique())
        
        print(f" 3Pt Shots after mapping for player 2544: {player_breakdown[(player_breakdown.PLAYER_ID==2544)&(player_breakdown.shot_description.str.contains('3P'))]['shot_count'].sum()}")
        
        # Calculate eFG%

        
        # Filter out invalid shot combinations
        '''
        invalid_masks = [
            (player_breakdown['shot_group'] == 'LAYUPS') & (player_breakdown['shot_type'] == '3PT Field Goal'),
            (player_breakdown['shot_group'] == 'POST_MOVES') & (player_breakdown['shot_type'] == '3PT Field Goal')
        ]
        for mask in invalid_masks:
            player_breakdown = player_breakdown[~mask]
        '''
        #print(f"Final shots for player 2544: {player_breakdown[player_breakdown.PLAYER_ID==2544]['shot_count'].sum()}")
        
        # Add year and save breakdown
        player_breakdown['year'] = year
        player_breakdown.to_csv(f'shot_breakdown/{year}_shotbreakdown.csv', index=False)
        
        # Create overall shot breakdown
        shot_breakdown = (
            df.groupby(['shot_description'])
            .agg(
                shot_count=('SHOT_ATTEMPTED_FLAG', 'sum'),
                shot_makes=('SHOT_MADE_FLAG', 'sum')
            )
            .reset_index()
            .rename(columns={})
        )
        
        shot_breakdown['year'] = year
        shot_breakdown['shot_group'] = shot_breakdown['shot_description'].map(category_map)
        all_types.append(shot_breakdown)
    
    return pd.concat(all_types)

all_shots = collect_types()


# Add No Shot category if needed
shot_categories,mapping=get_shot_categories_and_mapping()
category_map={}
for shot_type in shot_categories.keys():
    shotlist = shot_categories[shot_type]
    for shot in shotlist:
        category_map[shot]=shot_type

#all_shots['shot_group'] = all_shots['shot_description'].map(category_map)

other_categories = {
   
}

all_shots.dropna(subset='shot_description',inplace=True)

all_shots.to_csv('shot_types.csv')
all_shots
# Out:
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '3PT Jump Shot' 'Driving Layup' 'Hook Shot'
#  'Standard Dunk' 'Standard Layup' 'Tip Shot' '2PT Running Jump Shot'
#  'Driving Dunk' '3PT Running Jump Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '2PT Running Jump Shot' '3PT Jump Shot' 'Driving Dunk'
#  'Driving Layup' 'Hook Shot' 'No Shot' 'Standard Dunk' 'Standard Layup'
#  'Tip Shot' '3PT Running Jump Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '3PT Jump Shot' 'Driving Dunk' 'Driving Layup'
#  'Hook Shot' 'Standard Dunk' 'Standard Layup' 'Tip Shot'
#  '2PT Running Jump Shot' '3PT Running Jump Shot' 'No Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '3PT Jump Shot' 'Driving Layup' 'Hook Shot'
#  'Standard Dunk' 'Standard Layup' 'Tip Shot' '2PT Running Jump Shot'
#  'Driving Dunk' '3PT Running Jump Shot' 'No Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '3PT Jump Shot' 'Driving Dunk' 'Driving Layup'
#  'Hook Shot' 'Reverse Layup' 'Standard Dunk' 'Standard Layup' 'Tip Shot'
#  'Turnaround Hook Shot' '2PT Running Jump Shot' 'Finger Roll'
#  '2PT Turnaround Jump Shot' 'Driving Hook Shot' 'Alley Oop Dunk'
#  'Reverse Dunk' 'Running Hook Shot' 'Alley Oop Layup'
#  '3PT Running Jump Shot' '3PT Turnaround Jump Shot' 'No Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '2PT Running Jump Shot' '3PT Jump Shot' 'Driving Layup'
#  'Reverse Layup' 'Running Hook Shot' 'Standard Layup' 'Tip Shot'
#  '2PT Fadeaway Jump Shot' '2PT Turnaround Jump Shot'
#  '3PT Fadeaway Jump Shot' 'Finger Roll' 'Standard Dunk' 'Alley Oop Dunk'
#  'Alley Oop Layup' 'Driving Dunk' 'Hook Shot' 'Specialty Dunk'
#  'Turnaround Hook Shot' 'Driving Hook Shot' 'Reverse Dunk'
#  '3PT Running Jump Shot' '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '3PT Jump Shot' '2PT Fadeaway Jump Shot'
#  '2PT Running Jump Shot' '2PT Turnaround Jump Shot' 'Alley Oop Layup'
#  'Driving Layup' 'Finger Roll' 'Hook Shot' 'Reverse Layup'
#  'Standard Layup' 'Tip Shot' 'Driving Dunk' 'Driving Hook Shot'
#  'Running Hook Shot' 'Specialty Dunk' 'Standard Dunk'
#  'Turnaround Hook Shot' 'Alley Oop Dunk' 'Reverse Dunk'
#  '3PT Turnaround Jump Shot' '3PT Running Jump Shot'
#  '3PT Fadeaway Jump Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Jump Shot' '2PT Running Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Jump Shot' 'Driving Hook Shot'
#  'Driving Layup' 'Finger Roll' 'Reverse Layup' 'Standard Dunk'
#  'Standard Layup' 'Tip Shot' 'Alley Oop Dunk' 'Alley Oop Layup'
#  'Driving Dunk' 'Hook Shot' 'Running Hook Shot' 'Turnaround Hook Shot'
#  'Reverse Dunk' 'Specialty Dunk' '3PT Running Jump Shot'
#  '3PT Fadeaway Jump Shot' '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 217
# 2PT Field Goal    1375
# 3PT Field Goal     309
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 309
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Jump Shot' '2PT Turnaround Jump Shot'
#  '3PT Jump Shot' 'Driving Layup' 'Standard Layup' '2PT Running Jump Shot'
#  'Driving Hook Shot' 'Finger Roll' 'Hook Shot' 'Specialty Dunk'
#  'Standard Dunk' 'Tip Shot' 'Reverse Layup' 'Running Hook Shot'
#  'Turnaround Hook Shot' 'Alley Oop Dunk' 'Alley Oop Layup' 'Driving Dunk'
#  'Reverse Dunk' '3PT Fadeaway Jump Shot' '3PT Running Jump Shot'
#  '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 308
# 2PT Field Goal    1444
# 3PT Field Goal     379
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 379
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '3PT Jump Shot' '2PT Running Jump Shot' 'Driving Layup'
#  'Standard Layup' '2PT Fadeaway Jump Shot' '2PT Turnaround Jump Shot'
#  'Alley Oop Layup' 'Driving Dunk' 'Driving Hook Shot' 'Finger Roll'
#  'Hook Shot' 'Running Hook Shot' 'Standard Dunk' 'Tip Shot'
#  'Turnaround Hook Shot' 'Reverse Layup' 'Specialty Dunk' 'Alley Oop Dunk'
#  'Reverse Dunk' '3PT Running Jump Shot' '3PT Fadeaway Jump Shot'
#  '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 379
# 2PT Field Goal    1312
# 3PT Field Goal     309
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 309
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Jump Shot' 'Driving Layup' 'Standard Layup'
#  '3PT Jump Shot' 'Driving Dunk' 'Hook Shot' 'Standard Dunk' 'Tip Shot'
#  '2PT Running Jump Shot' '2PT Turnaround Jump Shot'
#  '3PT Running Jump Shot' 'Alley Oop Layup' 'Finger Roll'
#  'Running Hook Shot' 'Turnaround Hook Shot' 'Driving Hook Shot'
#  'Reverse Layup' 'Specialty Dunk' 'Alley Oop Dunk' 'Reverse Dunk'
#  '3PT Fadeaway Jump Shot' '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 309
# 2PT Field Goal    1283
# 3PT Field Goal     359
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 359
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Pullup Jump Shot' '2PT Running Jump Shot' '3PT Jump Shot'
#  '3PT Pullup Jump Shot' '3PT Running Jump Shot' '3PT Turnaround Jump Shot'
#  'Driving Dunk' 'Driving Layup' 'Reverse Layup' 'Standard Layup'
#  'Tip Shot' '2PT Turnaround Jump Shot' 'Hook Shot' 'Putback Dunk'
#  'Putback Layup' 'Standard Dunk' 'Turnaround Hook Shot'
#  'Driving Hook Shot' 'Reverse Dunk' 'Running Hook Shot' 'Finger Roll'
#  '2PT Step Back Jump Shot' '2PT Driving Jump Shot'
#  '3PT Step Back Jump Shot' 'Alley Oop Dunk' 'Alley Oop Layup'
#  '3PT Floating Jump Shot' '3PT Fadeaway Jump Shot']
#  3Pt Shots after mapping for player 2544: 359
# 2PT Field Goal    1230
# 3PT Field Goal     383
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 383
#
# Unique shot descriptions before mapping:
# ['2PT Driving Jump Shot' '2PT Fadeaway Jump Shot' '2PT Floating Jump Shot'
#  '2PT Jump Shot' '2PT Pullup Jump Shot' '2PT Running Jump Shot'
#  '2PT Step Back Jump Shot' '2PT Turnaround Jump Shot'
#  '3PT Fadeaway Jump Shot' '3PT Jump Shot' '3PT Pullup Jump Shot'
#  '3PT Running Jump Shot' '3PT Step Back Jump Shot'
#  '3PT Turnaround Jump Shot' 'Alley Oop Dunk' 'Alley Oop Layup'
#  'Driving Layup' 'Finger Roll' 'Putback Layup' 'Reverse Layup'
#  'Running Hook Shot' 'Standard Layup' 'Tip Shot' 'Hook Shot'
#  'Standard Dunk' 'Turnaround Hook Shot' 'Driving Dunk' 'Putback Dunk'
#  'Driving Hook Shot' 'Reverse Dunk']
#  3Pt Shots after mapping for player 2544: 383
# 2PT Field Goal    1141
# 3PT Field Goal     387
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 387
#
# Unique shot descriptions before mapping:
# ['2PT Driving Jump Shot' '2PT Fadeaway Jump Shot' '2PT Floating Jump Shot'
#  '2PT Jump Shot' '2PT Pullup Jump Shot' '2PT Running Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Jump Shot' '3PT Pullup Jump Shot'
#  'Driving Layup' 'Finger Roll' 'Putback Layup' 'Standard Layup'
#  '2PT Step Back Jump Shot' '3PT Fadeaway Jump Shot'
#  '3PT Running Jump Shot' '3PT Step Back Jump Shot'
#  '3PT Turnaround Jump Shot' 'Alley Oop Layup' 'Hook Shot' 'Reverse Layup'
#  'Running Hook Shot' 'Tip Shot' 'Standard Dunk' 'Driving Dunk'
#  'Alley Oop Dunk' 'Driving Hook Shot' 'Putback Dunk'
#  'Turnaround Hook Shot' 'Reverse Dunk' '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 387
# 2PT Field Goal    1206
# 3PT Field Goal     279
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 279
#
# Unique shot descriptions before mapping:
# ['2PT Driving Jump Shot' '2PT Fadeaway Jump Shot' '2PT Floating Jump Shot'
#  '2PT Jump Shot' '2PT Pullup Jump Shot' '2PT Running Jump Shot'
#  '2PT Step Back Jump Shot' '2PT Turnaround Jump Shot' '3PT Jump Shot'
#  '3PT Pullup Jump Shot' 'Driving Layup' 'Standard Layup'
#  '3PT Fadeaway Jump Shot' '3PT Running Jump Shot'
#  '3PT Step Back Jump Shot' 'Alley Oop Layup' 'Finger Roll' 'Hook Shot'
#  'Putback Dunk' 'Reverse Layup' 'Running Hook Shot' 'Tip Shot'
#  'Putback Layup' 'Standard Dunk' 'Turnaround Hook Shot' 'Driving Dunk'
#  'Alley Oop Dunk' 'Driving Hook Shot' 'Reverse Dunk'
#  '3PT Turnaround Jump Shot' '3PT Floating Jump Shot'
#  '3PT Driving Jump Shot']
#  3Pt Shots after mapping for player 2544: 279
# 2PT Field Goal    1020
# 3PT Field Goal     149
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 149
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Pullup Jump Shot' '2PT Running Jump Shot' '3PT Jump Shot'
#  '3PT Pullup Jump Shot' 'Driving Layup' 'Finger Roll' 'Putback Layup'
#  'Standard Layup' '2PT Turnaround Jump Shot' 'Hook Shot' 'Reverse Layup'
#  'Running Hook Shot' 'Standard Dunk' 'Tip Shot' 'Turnaround Hook Shot'
#  '2PT Driving Jump Shot' '2PT Step Back Jump Shot'
#  '3PT Fadeaway Jump Shot' '3PT Step Back Jump Shot'
#  '3PT Turnaround Jump Shot' 'Driving Dunk' 'Driving Hook Shot'
#  'Putback Dunk' 'Alley Oop Dunk' 'Alley Oop Layup' 'Reverse Dunk'
#  '3PT Running Jump Shot' '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 149
# 2PT Field Goal    1100
# 3PT Field Goal     254
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 254
#
# Unique shot descriptions before mapping:
# ['2PT Driving Jump Shot' '2PT Fadeaway Jump Shot' '2PT Floating Jump Shot'
#  '2PT Jump Shot' '2PT Pullup Jump Shot' '2PT Running Jump Shot'
#  '2PT Step Back Jump Shot' '2PT Turnaround Jump Shot' '3PT Jump Shot'
#  '3PT Pullup Jump Shot' '3PT Step Back Jump Shot' 'Driving Layup'
#  'Finger Roll' 'Putback Layup' 'Reverse Layup' 'Standard Layup'
#  'Driving Hook Shot' 'Hook Shot' 'Running Hook Shot' 'Tip Shot'
#  'Driving Dunk' 'Standard Dunk' 'Turnaround Hook Shot' 'Alley Oop Dunk'
#  'Alley Oop Layup' 'Putback Dunk' 'Reverse Dunk' '3PT Running Jump Shot'
#  '3PT Floating Jump Shot' '3PT Turnaround Jump Shot'
#  '3PT Fadeaway Jump Shot' '3PT Driving Jump Shot']
#  3Pt Shots after mapping for player 2544: 254
# 2PT Field Goal    1047
# 3PT Field Goal     306
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 306
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Jump Shot' '2PT Pullup Jump Shot'
#  '3PT Jump Shot' 'Driving Layup' 'Standard Layup' '2PT Driving Jump Shot'
#  '2PT Floating Jump Shot' '2PT Running Jump Shot'
#  '2PT Step Back Jump Shot' '3PT Fadeaway Jump Shot' '3PT Pullup Jump Shot'
#  '3PT Running Jump Shot' '3PT Step Back Jump Shot' 'Driving Hook Shot'
#  'Finger Roll' 'Hook Shot' 'Putback Layup' 'Reverse Layup'
#  'Running Hook Shot' 'Tip Shot' '2PT Turnaround Jump Shot' 'Standard Dunk'
#  'Driving Dunk' 'Putback Dunk' 'Alley Oop Dunk' 'Alley Oop Layup'
#  'Reverse Dunk' 'Turnaround Hook Shot' '3PT Turnaround Jump Shot'
#  '3PT Driving Jump Shot' '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 306
# 2PT Field Goal    940
# 3PT Field Goal    339
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 339
#
# Unique shot descriptions before mapping:
# ['2PT Driving Jump Shot' '2PT Fadeaway Jump Shot' '2PT Floating Jump Shot'
#  '2PT Jump Shot' '2PT Pullup Jump Shot' '2PT Running Jump Shot'
#  '2PT Step Back Jump Shot' '2PT Turnaround Jump Shot' '3PT Jump Shot'
#  'Driving Layup' 'Standard Layup' '3PT Pullup Jump Shot'
#  '3PT Running Jump Shot' '3PT Step Back Jump Shot'
#  '3PT Turnaround Jump Shot' 'Driving Hook Shot' 'Finger Roll' 'Hook Shot'
#  'Putback Layup' 'Reverse Layup' 'Running Hook Shot' 'Tip Shot'
#  'Alley Oop Dunk' 'Alley Oop Layup' 'Driving Dunk' 'Putback Dunk'
#  'Reverse Dunk' 'Standard Dunk' 'Turnaround Hook Shot'
#  '3PT Fadeaway Jump Shot' '3PT Floating Jump Shot' '3PT Driving Jump Shot']
#  3Pt Shots after mapping for player 2544: 339
# 2PT Field Goal    1134
# 3PT Field Goal     281
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 281
#
# Unique shot descriptions before mapping:
# ['2PT Driving Jump Shot' '2PT Fadeaway Jump Shot' '2PT Floating Jump Shot'
#  '2PT Jump Shot' '2PT Pullup Jump Shot' '2PT Running Jump Shot'
#  '2PT Step Back Jump Shot' '2PT Turnaround Jump Shot'
#  '3PT Floating Jump Shot' '3PT Jump Shot' '3PT Pullup Jump Shot'
#  '3PT Running Jump Shot' '3PT Step Back Jump Shot' 'Driving Hook Shot'
#  'Driving Layup' 'Finger Roll' 'Hook Shot' 'Putback Layup' 'Reverse Layup'
#  'Standard Layup' 'Alley Oop Dunk' 'Alley Oop Layup' 'Driving Dunk'
#  'Putback Dunk' 'Reverse Dunk' 'Specialty Dunk' 'Standard Dunk'
#  'Turnaround Hook Shot' '3PT Fadeaway Jump Shot'
#  '3PT Turnaround Jump Shot' 'No Shot' '3PT Driving Jump Shot'
#  'Running Hook Shot']
#  3Pt Shots after mapping for player 2544: 281
# 2PT Field Goal    1002
# 3PT Field Goal     341
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 341
#
# Unique shot descriptions before mapping:
# ['2PT Floating Jump Shot' '2PT Jump Shot' '2PT Pullup Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Jump Shot' 'Alley Oop Dunk'
#  'Driving Layup' 'Hook Shot' 'Putback Layup' 'Reverse Layup'
#  'Specialty Dunk' 'Standard Dunk' 'Standard Layup' 'Turnaround Hook Shot'
#  '2PT Driving Jump Shot' '2PT Fadeaway Jump Shot' '2PT Running Jump Shot'
#  '2PT Step Back Jump Shot' '3PT Pullup Jump Shot' '3PT Running Jump Shot'
#  '3PT Step Back Jump Shot' 'Driving Hook Shot' 'Finger Roll'
#  'Alley Oop Layup' 'Driving Dunk' 'Putback Dunk' 'Reverse Dunk'
#  '3PT Floating Jump Shot' 'No Shot' '3PT Fadeaway Jump Shot'
#  '3PT Turnaround Jump Shot' 'Running Hook Shot']
#  3Pt Shots after mapping for player 2544: 341
# 2PT Field Goal    1174
# 3PT Field Goal     406
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 406
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Pullup Jump Shot' '2PT Step Back Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Jump Shot' '3PT Pullup Jump Shot'
#  '3PT Step Back Jump Shot' 'Driving Hook Shot' 'Driving Layup'
#  'Finger Roll' 'Reverse Layup' 'Standard Layup' '2PT Running Jump Shot'
#  '3PT Fadeaway Jump Shot' '3PT Running Jump Shot'
#  '3PT Turnaround Jump Shot' 'Alley Oop Dunk' 'Alley Oop Layup'
#  'Driving Dunk' 'Hook Shot' 'Putback Dunk' 'Putback Layup' 'Reverse Dunk'
#  'Specialty Dunk' 'Standard Dunk' 'Turnaround Hook Shot'
#  '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 406
# 2PT Field Goal    767
# 3PT Field Goal    328
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 328
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Pullup Jump Shot' '2PT Running Jump Shot' '2PT Step Back Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Jump Shot' '3PT Pullup Jump Shot'
#  '3PT Running Jump Shot' '3PT Step Back Jump Shot' 'Alley Oop Dunk'
#  'Alley Oop Layup' 'Driving Dunk' 'Driving Hook Shot' 'Driving Layup'
#  'Finger Roll' 'Hook Shot' 'Putback Dunk' 'Putback Layup' 'Reverse Dunk'
#  'Reverse Layup' 'Specialty Dunk' 'Standard Dunk' 'Standard Layup'
#  'Turnaround Hook Shot' '3PT Fadeaway Jump Shot' '3PT Floating Jump Shot'
#  '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 328
# 2PT Field Goal    878
# 3PT Field Goal    425
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 425
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Pullup Jump Shot' '2PT Running Jump Shot' '2PT Step Back Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Jump Shot' '3PT Pullup Jump Shot'
#  '3PT Running Jump Shot' '3PT Step Back Jump Shot'
#  '3PT Turnaround Jump Shot' 'Alley Oop Dunk' 'Alley Oop Layup'
#  'Driving Dunk' 'Driving Hook Shot' 'Driving Layup' 'Finger Roll'
#  'Hook Shot' 'Putback Dunk' 'Putback Layup' 'Reverse Dunk' 'Reverse Layup'
#  'Specialty Dunk' 'Standard Dunk' 'Standard Layup' 'Turnaround Hook Shot'
#  '3PT Fadeaway Jump Shot' '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 425
# 2PT Field Goal    538
# 3PT Field Goal    285
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 285
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Pullup Jump Shot' '2PT Running Jump Shot' '2PT Step Back Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Fadeaway Jump Shot' '3PT Jump Shot'
#  '3PT Pullup Jump Shot' '3PT Running Jump Shot' '3PT Step Back Jump Shot'
#  '3PT Turnaround Jump Shot' 'Alley Oop Dunk' 'Alley Oop Layup'
#  'Driving Dunk' 'Driving Layup' 'Finger Roll' 'Hook Shot' 'Putback Dunk'
#  'Putback Layup' 'Reverse Dunk' 'Reverse Layup' 'Specialty Dunk'
#  'Standard Dunk' 'Standard Layup' 'Turnaround Hook Shot'
#  'Driving Hook Shot' '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 285
# 2PT Field Goal    773
# 3PT Field Goal    448
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 448
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Pullup Jump Shot' '2PT Step Back Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Jump Shot' '3PT Pullup Jump Shot'
#  '3PT Running Jump Shot' '3PT Step Back Jump Shot' 'Alley Oop Dunk'
#  'Alley Oop Layup' 'Driving Dunk' 'Driving Hook Shot' 'Driving Layup'
#  'Finger Roll' 'Hook Shot' 'Putback Dunk' 'Putback Layup' 'Reverse Dunk'
#  'Reverse Layup' 'Specialty Dunk' 'Standard Dunk' 'Standard Layup'
#  'Turnaround Hook Shot' '2PT Running Jump Shot' '3PT Fadeaway Jump Shot'
#  '3PT Floating Jump Shot' '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 448
# 2PT Field Goal    843
# 3PT Field Goal    376
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 376
#
# Unique shot descriptions before mapping:
# ['2PT Floating Jump Shot' '3PT Jump Shot' '3PT Pullup Jump Shot'
#  '3PT Running Jump Shot' '3PT Step Back Jump Shot' 'Driving Layup'
#  'Putback Layup' 'Specialty Dunk' 'Standard Dunk' 'Standard Layup'
#  '2PT Fadeaway Jump Shot' '2PT Jump Shot' '2PT Pullup Jump Shot'
#  '2PT Step Back Jump Shot' 'Alley Oop Layup' '2PT Running Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Turnaround Jump Shot' 'Driving Dunk'
#  'Finger Roll' 'Reverse Layup' 'Turnaround Hook Shot'
#  '3PT Fadeaway Jump Shot' 'Alley Oop Dunk' 'Driving Hook Shot' 'Hook Shot'
#  'Putback Dunk' 'Reverse Dunk' '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 376
# 2PT Field Goal    906
# 3PT Field Goal    363
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 363
#
# Unique shot descriptions before mapping:
# ['2PT Floating Jump Shot' '2PT Jump Shot' '3PT Jump Shot'
#  '3PT Pullup Jump Shot' '3PT Running Jump Shot' 'Alley Oop Layup'
#  'Driving Dunk' 'Driving Layup' 'Finger Roll' 'Putback Layup'
#  'Specialty Dunk' 'Standard Dunk' 'Standard Layup' '2PT Pullup Jump Shot'
#  '2PT Step Back Jump Shot' '2PT Turnaround Jump Shot'
#  '3PT Step Back Jump Shot' '3PT Turnaround Jump Shot'
#  '2PT Running Jump Shot' 'Reverse Layup' '2PT Fadeaway Jump Shot'
#  'Alley Oop Dunk' 'Driving Hook Shot' 'Hook Shot' 'Putback Dunk'
#  'Reverse Dunk' 'Turnaround Hook Shot' '3PT Fadeaway Jump Shot'
#  '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 363
# 2PT Field Goal    424
# 3PT Field Goal    198
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 198
#
# Unique shot descriptions before mapping:
# ['3PT Jump Shot' 'Alley Oop Dunk' 'Driving Layup' '2PT Fadeaway Jump Shot'
#  '2PT Jump Shot' '2PT Pullup Jump Shot' '2PT Step Back Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Pullup Jump Shot' '3PT Running Jump Shot'
#  '3PT Step Back Jump Shot' '3PT Turnaround Jump Shot' 'Standard Layup'
#  'Finger Roll' '2PT Floating Jump Shot' 'Driving Dunk' 'Driving Hook Shot'
#  'Hook Shot' 'Putback Dunk' 'Putback Layup' 'Reverse Dunk' 'Reverse Layup'
#  'Specialty Dunk' 'Standard Dunk' 'Turnaround Hook Shot' 'Alley Oop Layup'
#  '3PT Fadeaway Jump Shot' '2PT Running Jump Shot' '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 198
#          shot_description  shot_count  shot_makes  year           shot_group
# 0           2PT Jump Shot      181610       70352  1997    TWO_POINT_JUMPERS
# 1   2PT Running Jump Shot        7258        4878  1997    TWO_POINT_JUMPERS
# 2           3PT Jump Shot       40598       14210  1997  THREE_POINT_JUMPERS
# 3   3PT Running Jump Shot          68          20  1997  THREE_POINT_JUMPERS
# 4            Driving Dunk        2082        2028  1997                DUNKS
# ..                    ...         ...         ...   ...                  ...
# 24          Reverse Layup        1624        1070  2025               LAYUPS
# 25         Specialty Dunk        3828        3410  2025                DUNKS
# 26          Standard Dunk        4062        3692  2025                DUNKS
# 27         Standard Layup       16778       10044  2025               LAYUPS
# 28   Turnaround Hook Shot        2556        1256  2025           POST_MOVES
#
# [750 rows x 5 columns]

# %%
len(all_shots['shot_description'].unique())
# Out:
# 34

# %%
player_shots=pd.concat([pd.read_csv('shot_breakdown/'+str(year)+'_shotbreakdown.csv') for year in range(1997,2026)] )
player_shots.dropna(subset='shot_description',inplace=True)
player_shots

player_ids=player_shots['PLAYER_ID'].unique().tolist()


for player_id in player_ids:

    tempframe=player_shots[player_shots.PLAYER_ID==player_id]
    tempframe.to_csv('../extra_data/shot_averages/'+str(player_id)+'.csv',index=False)

# %%
import plotly.graph_objects as go
import pandas as pd

def create_shot_efficiency_chart(selected_player, selected_group, selected_year, custom_width=1200, custom_height=800):
    """
    Creates a shot efficiency comparison chart between a player and league averages.
    
    Parameters:
    -----------
    selected_player : str
        Player ID
    selected_group : str
        Shot group category (e.g., 'JUMP_SHOTS')
    selected_year : int
        Selected season year
    custom_width : int, optional
        Width of the chart (default: 1200)
    custom_height : int, optional
        Height of the chart (default: 800)
        
    Returns:
    --------
    plotly.graph_objects.Figure
        The complete figure object
    """
    
    # Load data
    avg_df = pd.read_csv('https://raw.githubusercontent.com/gabriel1200/shot_data/refs/heads/master/shot_types.csv')
    player_df = pd.read_csv(f'https://raw.githubusercontent.com/gabriel1200/shot_averages/refs/heads/main/{selected_player}.csv')
    
    # Filter data
    if selected_player:
        player_df = player_df[player_df['PLAYER_ID'] == int(selected_player)]
    group_df = player_df[player_df['shot_group'] == selected_group]
    
    # Process shot data
    shot_data = []
    chart_data = {'labels': [], 'player_pct': [], 'league_pct': [], 'attempts': []}
    
    for shot_desc in group_df['shot_description'].unique():
        player_shots = group_df[group_df['shot_description'] == shot_desc]
        league_avg = avg_df[(avg_df['shot_description'] == shot_desc) & 
                          (avg_df['year'] == int(selected_year))]
        
        if not player_shots.empty and not league_avg.empty:
            player_pct = (player_shots['shot_makes'].sum() / player_shots['shot_count'].sum()) * 100
            league_pct = league_avg['efg%'].iloc[0] * 100
            attempts = player_shots['shot_count'].sum()
            
            # Format long labels with line breaks
            formatted_desc = '<br>'.join([shot_desc[i:i+20] for i in range(0, len(shot_desc), 20)])
            
            chart_data['labels'].append(formatted_desc)
            chart_data['player_pct'].append(round(player_pct, 1))
            chart_data['league_pct'].append(round(league_pct, 1))
            chart_data['attempts'].append(attempts)
    
    # Create traces
    player_trace = go.Bar(
        name="Player Efficiency",
        x=chart_data["labels"],
        y=chart_data["player_pct"],
        marker=dict(
            color="rgba(59, 130, 246, 0.85)",  # blue-500 with opacity
            line=dict(color="rgba(59, 130, 246, 1)", width=1.5)
        ),
        hovertemplate="<b>%{x}</b><br>" +
                     "Efficiency: %{y:.1f}%<br>" +
                     f"Attempts: %{{text}}<br>" +
                     "<extra></extra>",
        text=chart_data["attempts"]
    )

    league_trace = go.Bar(
        name="League Average",
        x=chart_data["labels"],
        y=chart_data["league_pct"],
        marker=dict(
            color="rgba(239, 68, 68, 0.85)",  # red-500 with opacity
            line=dict(color="rgba(239, 68, 68, 1)", width=1.5)
        ),
        hovertemplate="<b>%{x}</b><br>" +
                     "League Avg: %{y:.1f}%<br>" +
                     "<extra></extra>"
    )

    # Create and customize figure
    fig = go.Figure(data=[player_trace, league_trace])
    
    # Update layout with improved styling
    fig.update_layout(
        title=dict(
            text=f"Shot Efficiency Comparison - {selected_group.replace('_', ' ').title()}",
            font=dict(size=24, color="#F3F4F6"),
            x=0.5,
            y=0.95
        ),
        legend=dict(
            title=dict(text="", font=dict(color="#F3F4F6")),
            font=dict(size=14, color="#F3F4F6"),
            bgcolor="rgba(0,0,0,0.5)",
            bordercolor="rgba(255,255,255,0.2)",
            borderwidth=1
        ),
        xaxis=dict(
            title=dict(
                text="Shot Types",
                font=dict(size=16, color="#F3F4F6")
            ),
            tickangle=45,
            tickfont=dict(size=12, color="#F3F4F6"),
            gridcolor="rgba(107, 114, 128, 0.2)",
            showgrid=True
        ),
        yaxis=dict(
            title=dict(
                text="Efficiency %",
                font=dict(size=16, color="#F3F4F6")
            ),
            tickfont=dict(size=12, color="#F3F4F6"),
            gridcolor="rgba(107, 114, 128, 0.2)",
            showgrid=True,
            range=[0, max(max(chart_data["player_pct"]), max(chart_data["league_pct"])) * 1.1]
        ),
        barmode="group",
        width=custom_width,
        height=custom_height,
        plot_bgcolor="rgba(0, 0, 0, 0)",
        paper_bgcolor="rgba(0, 0, 0, 0)",
        margin=dict(t=100, b=100, l=100, r=50),
        showlegend=True,
        bargap=0.15,
        bargroupgap=0.1
    )
    
    return fig

# Example usage:
fig = create_shot_efficiency_chart('2544', 'JUMP_SHOTS', 2025)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 139
#     136     return fig
#     138 # Example usage:
# --> 139 fig = create_shot_efficiency_chart('2544', 'JUMP_SHOTS', 2025)
#     140 fig.show()
#
# Cell In[4], line 123, in create_shot_efficiency_chart(selected_player, selected_group, selected_year, custom_width, custom_height)
#      88 fig = go.Figure(data=[player_trace, league_trace])
#      90 # Update layout with improved styling
#      91 fig.update_layout(
#      92     title=dict(
#      93         text=f"Shot Efficiency Comparison - {selected_group.replace('_', ' ').title()}",
#      94         font=dict(size=24, color="#F3F4F6"),
#      95         x=0.5,
#      96         y=0.95
#      97     ),
#      98     legend=dict(
#      99         title=dict(text="", font=dict(color="#F3F4F6")),
#     100         font=dict(size=14, color="#F3F4F6"),
#     101         bgcolor="rgba(0,0,0,0.5)",
#     102         bordercolor="rgba(255,255,255,0.2)",
#     103         borderwidth=1
#     104     ),
#     105     xaxis=dict(
#     106         title=dict(
#     107             text="Shot Types",
#     108             font=dict(size=16, color="#F3F4F6")
#     109         ),
#     110         tickangle=45,
#     111         tickfont=dict(size=12, color="#F3F4F6"),
#     112         gridcolor="rgba(107, 114, 128, 0.2)",
#     113         showgrid=True
#     114     ),
#     115     yaxis=dict(
#     116         title=dict(
#     117             text="Efficiency %",
#     118             font=dict(size=16, color="#F3F4F6")
#     119         ),
#     120         tickfont=dict(size=12, color="#F3F4F6"),
#     121         gridcolor="rgba(107, 114, 128, 0.2)",
#     122         showgrid=True,
# --> 123         range=[0, max(max(chart_data["player_pct"]), max(chart_data["league_pct"])) * 1.1]
#     124     ),
#     125     barmode="group",
#     126     width=custom_width,
#     127     height=custom_height,
#     128     plot_bgcolor="rgba(0, 0, 0, 0)",
#     129     paper_bgcolor="rgba(0, 0, 0, 0)",
#     130     margin=dict(t=100, b=100, l=100, r=50),
#     131     showlegend=True,
#     132     bargap=0.15,
#     133     bargroupgap=0.1
#     134 )
#     136 return fig
#
# ValueError: max() arg is an empty sequence
