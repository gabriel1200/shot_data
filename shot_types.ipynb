# %%
import pandas as pd
import os
import numpy as np
def get_shot_categories_and_mapping():
    # Updated shot categories with separated 2PT and 3PT jump shots
    shot_categories = {
        'TWO_POINT_JUMPERS': [
            '2PT Jump Shot',
            '2PT Pullup Jump Shot',
            '2PT Step Back Jump Shot',
            '2PT Fadeaway Jump Shot',
            '2PT Running Jump Shot',
            '2PT Turnaround Jump Shot',
            '2PT Driving Jump Shot'
        ],
        
        'THREE_POINT_JUMPERS': [
            '3PT Jump Shot',
            '3PT Pullup Jump Shot',
            '3PT Step Back Jump Shot',
            '3PT Fadeaway Jump Shot',
            '3PT Running Jump Shot',
            '3PT Turnaround Jump Shot',
            '3PT Driving Jump Shot'
        ],
        
        'LAYUPS': [
            'Standard Layup',
            'Driving Layup',
            'Finger Roll',
            'Reverse Layup',
            'Putback Layup',
            'Alley Oop Layup'
        ],
        
        'DUNKS': [
            'Standard Dunk',
            'Driving Dunk',
            'Reverse Dunk',
            'Putback Dunk',
            'Alley Oop Dunk',
            'Specialty Dunk'
        ],
        
        'POST_MOVES': [
            'Hook Shot',
            'Running Hook Shot',
            'Turnaround Hook Shot',
            'Driving Hook Shot'
        ],
        
        'FLOATING_SHOTS': [
            '2PT Floating Jump Shot',
            '3PT Floating Jump Shot'
        ],
        
        'TIP_SHOTS': [
            'Tip Shot'
        ],
        
        'NO_SHOT': ['No Shot']
    }
    
    # Updated mapping to include shot type distinction
    shot_mapping = {
        # 2PT Jump Shots
        'Jump Shot': lambda x: '3PT Jump Shot' if x == '3' else '2PT Jump Shot',
        'Pullup Jump shot': lambda x: '3PT Pullup Jump Shot' if x == '3' else '2PT Pullup Jump Shot',
        'Pullup Bank shot': lambda x: '3PT Pullup Jump Shot' if x == '3' else '2PT Pullup Jump Shot',
        'Step Back Jump shot': lambda x: '3PT Step Back Jump Shot' if x == '3' else '2PT Step Back Jump Shot',
        'Step Back Bank Jump Shot': lambda x: '3PT Step Back Jump Shot' if x == '3' else '2PT Step Back Jump Shot',
        'Fadeaway Jump Shot': lambda x: '3PT Fadeaway Jump Shot' if x == '3' else '2PT Fadeaway Jump Shot',
        'Fadeaway Bank shot': lambda x: '3PT Fadeaway Jump Shot' if x == '3' else '2PT Fadeaway Jump Shot',
        'Running Jump Shot': lambda x: '3PT Running Jump Shot' if x == '3' else '2PT Running Jump Shot',
        'Running Pull-Up Jump Shot': lambda x: '3PT Running Jump Shot' if x == '3' else '2PT Running Jump Shot',
        'Running Bank shot': lambda x: '3PT Running Jump Shot' if x == '3' else '2PT Running Jump Shot',
        'Jump Bank Shot': lambda x: '3PT Jump Shot' if x == '3' else '2PT Jump Shot',
        'Turnaround Jump Shot': lambda x: '3PT Turnaround Jump Shot' if x == '3' else '2PT Turnaround Jump Shot',
        'Turnaround Fadeaway shot': lambda x: '3PT Turnaround Jump Shot' if x == '3' else '2PT Turnaround Jump Shot',
        'Turnaround Bank shot': lambda x: '3PT Turnaround Jump Shot' if x == '3' else '2PT Turnaround Jump Shot',
        'Turnaround Fadeaway Bank Jump Shot': lambda x: '3PT Turnaround Jump Shot' if x == '3' else '2PT Turnaround Jump Shot',
        'Driving Jump shot': lambda x: '3PT Driving Jump Shot' if x == '3' else '2PT Driving Jump Shot',
        'Driving Bank shot': lambda x: '3PT Driving Jump Shot' if x == '3' else '2PT Driving Jump Shot',
        'Floating Jump shot': lambda x: '3PT Floating Jump Shot' if x == '3' else '2PT Floating Jump Shot',
        'Driving Floating Jump Shot': lambda x: '3PT Floating Jump Shot' if x == '3' else '2PT Floating Jump Shot',
        'Driving Floating Bank Jump Shot': lambda x: '3PT Floating Jump Shot' if x == '3' else '2PT Floating Jump Shot',
        
        # Non-jump shots (remain the same regardless of shot type)
        'Layup Shot': 'Standard Layup',
        'Running Layup Shot': 'Standard Layup',
        'Cutting Layup Shot': 'Standard Layup',
        'Driving Layup Shot': 'Driving Layup',
        'Driving Reverse Layup Shot': 'Driving Layup',
        'Reverse Layup Shot': 'Reverse Layup',
        'Running Reverse Layup Shot': 'Reverse Layup',
        'Tip Layup Shot': 'Putback Layup',
        'Putback Layup Shot': 'Putback Layup',
        'Alley Oop Layup shot': 'Alley Oop Layup',
        'Running Alley Oop Layup Shot': 'Alley Oop Layup',
        'Driving Finger Roll Layup Shot': 'Finger Roll',
        'Finger Roll Layup Shot': 'Finger Roll',
        'Running Finger Roll Layup Shot': 'Finger Roll',
        'Cutting Finger Roll Layup Shot': 'Finger Roll',
        'Finger Roll Shot': 'Finger Roll',
        'Running Finger Roll Shot': 'Finger Roll',
        'Turnaround Finger Roll Shot': 'Finger Roll',
        'Driving Finger Roll Shot': 'Finger Roll',
        'Dunk Shot': 'Standard Dunk',
        'Slam Dunk Shot': 'Standard Dunk',
        'Running Dunk Shot': 'Standard Dunk',
        'Running Slam Dunk Shot': 'Standard Dunk',
        'Driving Dunk Shot': 'Driving Dunk',
        'Driving Slam Dunk Shot': 'Driving Dunk',
        'Driving Reverse Dunk Shot': 'Reverse Dunk',
        'Reverse Dunk Shot': 'Reverse Dunk',
        'Reverse Slam Dunk Shot': 'Reverse Dunk',
        'Running Reverse Dunk Shot': 'Reverse Dunk',
        'Putback Dunk Shot': 'Putback Dunk',
        'Putback Reverse Dunk Shot': 'Putback Dunk',
        'Putback Slam Dunk Shot': 'Putback Dunk',
        'Alley Oop Dunk Shot': 'Alley Oop Dunk',
        'Running Alley Oop Dunk Shot': 'Alley Oop Dunk',
        'Cutting Dunk Shot': 'Specialty Dunk',
        'Tip Dunk Shot': 'Specialty Dunk',
        'Follow Up Dunk Shot': 'Specialty Dunk',
        'Hook Shot': 'Hook Shot',
        'Jump Hook Shot': 'Hook Shot',
        'Running Hook Shot': 'Running Hook Shot',
        'Running Bank Hook Shot': 'Running Hook Shot',
        'Turnaround Hook Shot': 'Turnaround Hook Shot',
        'Turnaround Bank Hook Shot': 'Turnaround Hook Shot',
        'Driving Hook Shot': 'Driving Hook Shot',
        'Driving Bank Hook Shot': 'Driving Hook Shot',
        'Hook Bank Shot': 'Hook Shot',
        'Jump Bank Hook Shot': 'Hook Shot',
        'Tip Shot': 'Tip Shot',
        'Running Tip Shot': 'Tip Shot',
        'No Shot': 'No Shot'
    }
    
    return shot_categories, shot_mapping

def collect_year(year,ps=False):
    trail ='ps' if ps else ''
    path = 'team/'+str(year)+trail+'/'
    arr = os.listdir(path)
    csvs = [file for file in arr if '.csv' in file and file !='avg.csv']
    frames= []
    for csv in csvs:
        df=pd.read_csv(path+csv)
        frames.append(df)
    master = pd.concat(frames)
    return master

def collect_types(ps=False):
    trail ='ps' if ps else ''
    end_year = 2025 if ps else 2026
    shot_categories, mapping = get_shot_categories_and_mapping()
    category_map = {}
    
    # Build category mapping dictionary
    for shot_type, shotlist in shot_categories.items():
        for shot in shotlist:
            category_map[shot] = shot_type

    all_types = []
    
    for year in range(1997, end_year):
        df = collect_year(year,ps)

        threes = ['24+ ft.', 'Back Court Shot']


        df['SHOT_TYPE'] = df['SHOT_ZONE_RANGE'].apply(lambda x:'3PT Field Goal' if x in threes else '2PT Field Goal')

        #df['SHOT_TYPE'].fillna('2PT Field Goal',inplace=True)
     

        value_map = {'2PT Field Goal': '2', '3PT Field Goal': '3'}
        if year>2004:
            print(df[df.PLAYER_ID==2544]['SHOT_TYPE'].value_counts())
        
            print(f" 3Pt Shots before mapping for player 2544: {df[(df.PLAYER_ID==2544)&(df.SHOT_TYPE.str.contains('3P'))]['SHOT_ATTEMPTED_FLAG'].sum()}")
        df['SHOT_TYPE'] = df['SHOT_TYPE'].map(value_map)

        df['shot_description'] = df.apply(
            lambda row: mapping[row['ACTION_TYPE']](row['SHOT_TYPE']) 
            if callable(mapping[row['ACTION_TYPE']]) 
            else mapping[row['ACTION_TYPE']], 
            axis=1
        )

        
        df['SHOT_ATTEMPTED_FLAG'] = df['SHOT_ATTEMPTED_FLAG'].astype(int)
        df['SHOT_MADE_FLAG'] = df['SHOT_MADE_FLAG'].astype(int)
        
        # Convert shot type to '2' or '3'
        df['SHOT_TYPE'] = np.where(df['SHOT_TYPE'].str.contains('3pt', case=False, na=False), '3', '2')
        
        # Create player breakdown
        player_breakdown = (
            df.groupby(['PLAYER_NAME', 'PLAYER_ID', 'shot_description'])
            .agg(
                shot_count=('SHOT_ATTEMPTED_FLAG', 'sum'),
                shot_makes=('SHOT_MADE_FLAG', 'sum'),
            )
            .reset_index()
        )
        
        # Apply the mapping with shot type consideration

        # Debug unique values before mapping
        print("\nUnique shot descriptions before mapping:")
        print(player_breakdown['shot_description'].unique())
        
        # Apply mappings and check for missing values
        #player_breakdown['old_description'] = player_breakdown['shot_description']
       
        
        # Debug missing mappings
        missing_mappings = player_breakdown[player_breakdown['shot_description'].isna()]
        if not missing_mappings.empty:
            print("\nMissing mappings found for:")
            print(missing_mappings['old_description'].unique())
        
        # Apply category mapping
        player_breakdown['shot_group'] = player_breakdown['shot_description'].map(category_map)
        
        # Debug category mapping
        missing_categories = player_breakdown[player_breakdown['shot_group'].isna()]
        if not missing_categories.empty:
            print("\nMissing categories found for:")
            print(missing_categories['shot_description'].unique())
        
        print(f" 3Pt Shots after mapping for player 2544: {player_breakdown[(player_breakdown.PLAYER_ID==2544)&(player_breakdown.shot_description.str.contains('3P'))]['shot_count'].sum()}")
        
        # Calculate eFG%

        
        # Filter out invalid shot combinations
        '''
        invalid_masks = [
            (player_breakdown['shot_group'] == 'LAYUPS') & (player_breakdown['shot_type'] == '3PT Field Goal'),
            (player_breakdown['shot_group'] == 'POST_MOVES') & (player_breakdown['shot_type'] == '3PT Field Goal')
        ]
        for mask in invalid_masks:
            player_breakdown = player_breakdown[~mask]
        '''
        #print(f"Final shots for player 2544: {player_breakdown[player_breakdown.PLAYER_ID==2544]['shot_count'].sum()}")
        
        # Add year and save breakdown
        player_breakdown['year'] = year
        player_breakdown.to_csv(f'shot_breakdown/{year}{trail}_shotbreakdown.csv', index=False)
        
        # Create overall shot breakdown
        shot_breakdown = (
            df.groupby(['shot_description'])
            .agg(
                shot_count=('SHOT_ATTEMPTED_FLAG', 'sum'),
                shot_makes=('SHOT_MADE_FLAG', 'sum')
            )
            .reset_index()
            .rename(columns={})
        )
        
        shot_breakdown['year'] = year
        shot_breakdown['shot_group'] = shot_breakdown['shot_description'].map(category_map)
        all_types.append(shot_breakdown)
    
    return pd.concat(all_types)
ps=True
all_shots = collect_types(ps)


# Add No Shot category if needed
shot_categories,mapping=get_shot_categories_and_mapping()
category_map={}
for shot_type in shot_categories.keys():
    shotlist = shot_categories[shot_type]
    for shot in shotlist:
        category_map[shot]=shot_type

#all_shots['shot_group'] = all_shots['shot_description'].map(category_map)

other_categories = {
   
}

all_shots.dropna(subset='shot_description',inplace=True)
if ps == False:
    all_shots.to_csv('shot_types.csv')
else:

    all_shots.to_csv('shot_types_ps.csv')
all_shots
# Out:
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '3PT Jump Shot' 'Driving Layup' 'Standard Layup'
#  'Tip Shot' 'Hook Shot' 'Standard Dunk' '2PT Running Jump Shot'
#  'Driving Dunk' '3PT Running Jump Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' 'Driving Layup' 'Standard Dunk' 'Standard Layup'
#  'Tip Shot' '2PT Running Jump Shot' '3PT Jump Shot' 'Driving Dunk'
#  'Hook Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '2PT Running Jump Shot' '3PT Jump Shot' 'Driving Layup'
#  'Standard Layup' 'Tip Shot' 'Driving Dunk' 'Hook Shot' 'Standard Dunk'
#  '3PT Running Jump Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '2PT Running Jump Shot' 'Driving Layup' 'Standard Dunk'
#  'Standard Layup' 'Tip Shot' '3PT Jump Shot' 'Driving Dunk' 'Hook Shot'
#  '3PT Running Jump Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '2PT Running Jump Shot' '2PT Turnaround Jump Shot'
#  '3PT Jump Shot' 'Driving Layup' 'Finger Roll' 'Reverse Layup'
#  'Standard Dunk' 'Standard Layup' 'Driving Dunk' 'Hook Shot' 'Tip Shot'
#  'Running Hook Shot' 'Driving Hook Shot' 'Turnaround Hook Shot'
#  'Alley Oop Dunk' 'Reverse Dunk' 'Alley Oop Layup' '3PT Running Jump Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '2PT Running Jump Shot' '3PT Jump Shot' 'Driving Layup'
#  'Standard Layup' '2PT Turnaround Jump Shot' 'Alley Oop Layup'
#  'Finger Roll' 'Hook Shot' 'Running Hook Shot' 'Standard Dunk' 'Tip Shot'
#  'Turnaround Hook Shot' '2PT Fadeaway Jump Shot' 'Reverse Layup'
#  'Driving Dunk' 'Alley Oop Dunk' 'Reverse Dunk' 'Specialty Dunk'
#  'Driving Hook Shot' '3PT Running Jump Shot' '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Jump Shot' '2PT Turnaround Jump Shot'
#  '3PT Jump Shot' 'Driving Layup' 'Finger Roll' 'Standard Layup'
#  'Hook Shot' 'Reverse Dunk' 'Running Hook Shot' 'Standard Dunk' 'Tip Shot'
#  '2PT Running Jump Shot' '3PT Running Jump Shot' 'Driving Hook Shot'
#  'Reverse Layup' 'Driving Dunk' 'Specialty Dunk' 'Alley Oop Dunk'
#  'Alley Oop Layup' 'Turnaround Hook Shot' '3PT Fadeaway Jump Shot']
#  3Pt Shots after mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '2PT Turnaround Jump Shot' 'Driving Dunk' 'Driving Layup'
#  'Hook Shot' 'Standard Dunk' 'Standard Layup' '2PT Fadeaway Jump Shot'
#  '3PT Jump Shot' 'Alley Oop Dunk' 'Driving Hook Shot' 'Finger Roll'
#  'Reverse Layup' 'Specialty Dunk' 'Tip Shot' '2PT Running Jump Shot'
#  'Running Hook Shot' 'Alley Oop Layup' 'Reverse Dunk'
#  'Turnaround Hook Shot' '3PT Running Jump Shot' '3PT Turnaround Jump Shot'
#  '3PT Fadeaway Jump Shot']
#  3Pt Shots after mapping for player 2544: 0
# Series([], Name: SHOT_TYPE, dtype: int64)
#  3Pt Shots before mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '3PT Jump Shot' 'Standard Layup' '2PT Fadeaway Jump Shot'
#  '2PT Running Jump Shot' 'Driving Layup' 'Hook Shot' 'Standard Dunk'
#  'Reverse Layup' 'Specialty Dunk' '2PT Turnaround Jump Shot' 'Finger Roll'
#  'Running Hook Shot' 'Tip Shot' 'Alley Oop Dunk' 'Alley Oop Layup'
#  'Driving Dunk' 'Reverse Dunk' '3PT Running Jump Shot'
#  'Turnaround Hook Shot' '3PT Fadeaway Jump Shot'
#  '3PT Turnaround Jump Shot' 'Driving Hook Shot']
#  3Pt Shots after mapping for player 2544: 0
# 2PT Field Goal    244
# 3PT Field Goal     63
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 63
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Jump Shot' 'Driving Dunk' 'Driving Layup'
#  'Finger Roll' 'Hook Shot' 'Reverse Layup' 'Running Hook Shot'
#  'Standard Dunk' 'Standard Layup' 'Turnaround Hook Shot'
#  '2PT Turnaround Jump Shot' 'Tip Shot' '2PT Running Jump Shot'
#  'Driving Hook Shot' '3PT Jump Shot' 'Alley Oop Layup' 'Alley Oop Dunk'
#  'Reverse Dunk' 'Specialty Dunk' '3PT Running Jump Shot'
#  '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 63
# 2PT Field Goal    324
# 3PT Field Goal     75
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 75
#
# Unique shot descriptions before mapping:
# ['Driving Layup' '2PT Jump Shot' 'Hook Shot' 'Standard Layup'
#  '2PT Fadeaway Jump Shot' '2PT Turnaround Jump Shot' '3PT Jump Shot'
#  'Finger Roll' 'Reverse Layup' 'Running Hook Shot' 'Standard Dunk'
#  'Tip Shot' '2PT Running Jump Shot' 'Alley Oop Dunk' 'Reverse Dunk'
#  'Specialty Dunk' 'Driving Hook Shot' 'Turnaround Hook Shot'
#  'Driving Dunk' '3PT Running Jump Shot' '3PT Fadeaway Jump Shot'
#  'Alley Oop Layup' '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 75
# 2PT Field Goal    205
# 3PT Field Goal     70
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 70
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '2PT Running Jump Shot' '3PT Jump Shot' 'Driving Layup'
#  'Reverse Layup' 'Standard Layup' '2PT Pullup Jump Shot'
#  '2PT Turnaround Jump Shot' 'Hook Shot' 'Finger Roll' 'Putback Dunk'
#  'Putback Layup' 'Running Hook Shot' 'Standard Dunk' 'Tip Shot'
#  'Turnaround Hook Shot' '2PT Fadeaway Jump Shot' '2PT Floating Jump Shot'
#  '2PT Step Back Jump Shot' '3PT Fadeaway Jump Shot' 'Alley Oop Dunk'
#  'Alley Oop Layup' 'Driving Dunk' 'Reverse Dunk' 'Driving Hook Shot'
#  '2PT Driving Jump Shot' '3PT Running Jump Shot' '3PT Step Back Jump Shot'
#  '3PT Pullup Jump Shot' '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 70
# 2PT Field Goal    231
# 3PT Field Goal     81
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 81
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Pullup Jump Shot' '2PT Running Jump Shot' '2PT Step Back Jump Shot'
#  '3PT Jump Shot' '3PT Pullup Jump Shot' '3PT Running Jump Shot'
#  'Alley Oop Layup' 'Driving Hook Shot' 'Driving Layup' 'Finger Roll'
#  'Hook Shot' 'Reverse Layup' 'Standard Layup' 'Tip Shot'
#  '2PT Turnaround Jump Shot' 'Putback Dunk' 'Putback Layup'
#  'Running Hook Shot' 'Standard Dunk' 'Driving Dunk' 'Reverse Dunk'
#  'Alley Oop Dunk' 'Turnaround Hook Shot' '2PT Driving Jump Shot'
#  '3PT Step Back Jump Shot' '3PT Turnaround Jump Shot'
#  '3PT Fadeaway Jump Shot']
#  3Pt Shots after mapping for player 2544: 81
# 2PT Field Goal    161
# 3PT Field Goal     50
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 50
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '3PT Jump Shot' 'Reverse Layup' 'Standard Layup'
#  '2PT Driving Jump Shot' '2PT Fadeaway Jump Shot'
#  '2PT Turnaround Jump Shot' 'Alley Oop Layup' 'Driving Dunk'
#  'Driving Hook Shot' 'Driving Layup' 'Hook Shot' 'Putback Dunk'
#  'Putback Layup' 'Running Hook Shot' 'Standard Dunk' 'Tip Shot'
#  'Turnaround Hook Shot' '2PT Floating Jump Shot' '2PT Pullup Jump Shot'
#  '2PT Running Jump Shot' 'Alley Oop Dunk' 'Reverse Dunk' 'Finger Roll'
#  '2PT Step Back Jump Shot' '3PT Running Jump Shot' '3PT Pullup Jump Shot'
#  '3PT Step Back Jump Shot' '3PT Fadeaway Jump Shot'
#  '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 50
# 2PT Field Goal    288
# 3PT Field Goal     85
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 85
#
# Unique shot descriptions before mapping:
# ['2PT Driving Jump Shot' '2PT Jump Shot' '2PT Pullup Jump Shot'
#  '2PT Running Jump Shot' '2PT Step Back Jump Shot' '3PT Jump Shot'
#  'Driving Layup' 'Hook Shot' 'Standard Layup' 'Tip Shot'
#  '2PT Fadeaway Jump Shot' '2PT Turnaround Jump Shot' 'Reverse Layup'
#  'Standard Dunk' 'Alley Oop Dunk' 'Putback Dunk' 'Putback Layup'
#  'Running Hook Shot' 'Turnaround Hook Shot' 'Driving Dunk' 'Finger Roll'
#  '2PT Floating Jump Shot' 'Alley Oop Layup' '3PT Pullup Jump Shot'
#  '3PT Running Jump Shot' 'Driving Hook Shot' 'Reverse Dunk'
#  '3PT Step Back Jump Shot' '3PT Turnaround Jump Shot'
#  '3PT Fadeaway Jump Shot']
#  3Pt Shots after mapping for player 2544: 85
# 2PT Field Goal    417
# 3PT Field Goal     85
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 85
#
# Unique shot descriptions before mapping:
# ['2PT Jump Shot' '2PT Fadeaway Jump Shot' '2PT Pullup Jump Shot'
#  '2PT Step Back Jump Shot' '2PT Turnaround Jump Shot' '3PT Jump Shot'
#  'Driving Layup' 'Finger Roll' 'Reverse Layup' 'Standard Dunk'
#  'Standard Layup' 'Tip Shot' 'Alley Oop Dunk' 'Driving Hook Shot'
#  'Hook Shot' 'Putback Dunk' '2PT Running Jump Shot'
#  '2PT Driving Jump Shot' 'Driving Dunk' '3PT Fadeaway Jump Shot'
#  '3PT Pullup Jump Shot' 'Putback Layup' 'Alley Oop Layup'
#  'Running Hook Shot' 'Reverse Dunk' 'Turnaround Hook Shot'
#  '2PT Floating Jump Shot' '3PT Turnaround Jump Shot'
#  '3PT Running Jump Shot' '3PT Step Back Jump Shot']
#  3Pt Shots after mapping for player 2544: 85
# 2PT Field Goal    336
# 3PT Field Goal     96
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 96
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Running Jump Shot' '2PT Step Back Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Jump Shot' '3PT Pullup Jump Shot'
#  'Driving Layup' 'Running Hook Shot' 'Standard Layup'
#  '2PT Driving Jump Shot' 'Alley Oop Layup' 'Driving Dunk' 'Hook Shot'
#  'Putback Dunk' 'Putback Layup' 'Standard Dunk' 'Tip Shot'
#  'Turnaround Hook Shot' 'Alley Oop Dunk' 'Finger Roll'
#  '2PT Pullup Jump Shot' '3PT Step Back Jump Shot' 'Reverse Dunk'
#  'Reverse Layup' 'Driving Hook Shot' '3PT Fadeaway Jump Shot'
#  '3PT Running Jump Shot' '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 96
# 2PT Field Goal    254
# 3PT Field Goal     86
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 86
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Jump Shot' '3PT Jump Shot' 'Driving Layup'
#  'Finger Roll' 'Putback Dunk' 'Standard Dunk' 'Standard Layup'
#  '2PT Turnaround Jump Shot' 'Hook Shot' 'Tip Shot' 'Turnaround Hook Shot'
#  '2PT Driving Jump Shot' '2PT Floating Jump Shot' '2PT Running Jump Shot'
#  '2PT Step Back Jump Shot' 'Alley Oop Dunk' 'Alley Oop Layup'
#  'Driving Hook Shot' 'Putback Layup' 'Reverse Layup' 'Driving Dunk'
#  '2PT Pullup Jump Shot' '3PT Pullup Jump Shot' '3PT Step Back Jump Shot'
#  'Running Hook Shot' '3PT Running Jump Shot' '3PT Turnaround Jump Shot'
#  'Reverse Dunk' '3PT Fadeaway Jump Shot' '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 86
# 2PT Field Goal    434
# 3PT Field Goal    110
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 110
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Running Jump Shot' '3PT Jump Shot' 'Driving Layup' 'Reverse Layup'
#  'Standard Layup' '2PT Driving Jump Shot' '2PT Pullup Jump Shot'
#  '2PT Step Back Jump Shot' '2PT Turnaround Jump Shot' 'Alley Oop Dunk'
#  'Alley Oop Layup' 'Driving Dunk' 'Driving Hook Shot' 'Hook Shot'
#  'Putback Dunk' 'Putback Layup' 'Running Hook Shot' 'Standard Dunk'
#  'Tip Shot' 'Turnaround Hook Shot' '3PT Step Back Jump Shot' 'Finger Roll'
#  '3PT Pullup Jump Shot' '3PT Running Jump Shot' '3PT Fadeaway Jump Shot'
#  'Reverse Dunk' '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 110
# 2PT Field Goal    323
# 3PT Field Goal     94
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 94
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Pullup Jump Shot' '2PT Step Back Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Jump Shot' '3PT Running Jump Shot'
#  '3PT Step Back Jump Shot' 'Alley Oop Dunk' 'Alley Oop Layup'
#  'Driving Dunk' 'Driving Hook Shot' 'Driving Layup' 'Finger Roll'
#  'Hook Shot' 'Putback Layup' 'Reverse Layup' 'Standard Dunk'
#  'Standard Layup' 'Turnaround Hook Shot' 'Putback Dunk' 'Specialty Dunk'
#  '2PT Driving Jump Shot' '2PT Running Jump Shot' '3PT Pullup Jump Shot'
#  '3PT Turnaround Jump Shot' 'Reverse Dunk' '3PT Fadeaway Jump Shot'
#  '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 94
# 2PT Field Goal    277
# 3PT Field Goal    107
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 107
#
# Unique shot descriptions before mapping:
# ['3PT Jump Shot' 'Hook Shot' '2PT Fadeaway Jump Shot'
#  '2PT Floating Jump Shot' '2PT Jump Shot' '2PT Pullup Jump Shot'
#  '2PT Step Back Jump Shot' '2PT Turnaround Jump Shot' 'Alley Oop Dunk'
#  'Alley Oop Layup' 'Driving Dunk' 'Driving Hook Shot' 'Driving Layup'
#  'Finger Roll' 'Putback Dunk' 'Putback Layup' 'Specialty Dunk'
#  'Standard Dunk' 'Standard Layup' 'Turnaround Hook Shot'
#  '3PT Pullup Jump Shot' 'Reverse Layup' '2PT Running Jump Shot' 'No Shot'
#  '3PT Fadeaway Jump Shot' '2PT Driving Jump Shot' '3PT Running Jump Shot'
#  '3PT Step Back Jump Shot' '3PT Turnaround Jump Shot' 'Reverse Dunk'
#  '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 107
# 2PT Field Goal    397
# 3PT Field Goal    113
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 113
#
# Unique shot descriptions before mapping:
# ['3PT Jump Shot' 'Driving Layup' '3PT Pullup Jump Shot' 'Standard Layup'
#  '2PT Jump Shot' '2PT Pullup Jump Shot' '2PT Turnaround Jump Shot'
#  'Reverse Layup' '2PT Fadeaway Jump Shot' '2PT Floating Jump Shot'
#  '2PT Step Back Jump Shot' 'Alley Oop Dunk' 'Alley Oop Layup'
#  'Driving Dunk' 'Driving Hook Shot' 'Finger Roll' 'Hook Shot'
#  'Putback Layup' 'Specialty Dunk' 'Standard Dunk' 'Turnaround Hook Shot'
#  '3PT Step Back Jump Shot' 'Reverse Dunk' '3PT Fadeaway Jump Shot'
#  'Putback Dunk' '3PT Running Jump Shot' '2PT Running Jump Shot'
#  '3PT Floating Jump Shot' '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 113
# Series([], Name: SHOT_TYPE, dtype: int64)
#  3Pt Shots before mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Pullup Jump Shot' '2PT Running Jump Shot' '2PT Step Back Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Jump Shot' '3PT Pullup Jump Shot'
#  '3PT Step Back Jump Shot' 'Driving Dunk' 'Driving Layup' 'Finger Roll'
#  'Putback Dunk' 'Putback Layup' 'Specialty Dunk' 'Standard Dunk'
#  'Standard Layup' 'Alley Oop Layup' 'Driving Hook Shot' 'Hook Shot'
#  'Turnaround Hook Shot' 'Reverse Layup' 'Alley Oop Dunk'
#  '3PT Running Jump Shot' '3PT Fadeaway Jump Shot'
#  '3PT Turnaround Jump Shot' '3PT Floating Jump Shot' 'Reverse Dunk']
#  3Pt Shots after mapping for player 2544: 0
# 2PT Field Goal    263
# 3PT Field Goal    119
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 119
#
# Unique shot descriptions before mapping:
# ['2PT Floating Jump Shot' '2PT Step Back Jump Shot' '3PT Jump Shot'
#  '3PT Pullup Jump Shot' '3PT Running Jump Shot' 'Driving Hook Shot'
#  'Driving Layup' 'Finger Roll' '2PT Fadeaway Jump Shot' '2PT Jump Shot'
#  '2PT Turnaround Jump Shot' 'Hook Shot' 'Putback Dunk' 'Putback Layup'
#  'Standard Layup' 'Turnaround Hook Shot' '2PT Pullup Jump Shot'
#  '3PT Step Back Jump Shot' '3PT Floating Jump Shot' 'Driving Dunk'
#  'Reverse Layup' 'Specialty Dunk' 'Standard Dunk' 'Alley Oop Dunk'
#  '2PT Running Jump Shot' '3PT Turnaround Jump Shot' 'Alley Oop Layup'
#  'Reverse Dunk' '3PT Fadeaway Jump Shot']
#  3Pt Shots after mapping for player 2544: 119
# 2PT Field Goal    66
# 3PT Field Goal    48
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 48
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Pullup Jump Shot' '2PT Step Back Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Jump Shot' '3PT Pullup Jump Shot'
#  '3PT Running Jump Shot' '3PT Step Back Jump Shot' 'Alley Oop Dunk'
#  'Driving Dunk' 'Driving Layup' 'Hook Shot' 'Putback Layup' 'Reverse Dunk'
#  'Reverse Layup' 'Specialty Dunk' 'Standard Dunk' 'Standard Layup'
#  'Turnaround Hook Shot' 'Alley Oop Layup' 'Finger Roll'
#  'Driving Hook Shot' 'Putback Dunk' '2PT Running Jump Shot'
#  '3PT Fadeaway Jump Shot' '3PT Turnaround Jump Shot'
#  '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 48
# Series([], Name: SHOT_TYPE, dtype: int64)
#  3Pt Shots before mapping for player 2544: 0
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Jump Shot' '2PT Pullup Jump Shot'
#  '2PT Step Back Jump Shot' '2PT Turnaround Jump Shot' '3PT Jump Shot'
#  '3PT Pullup Jump Shot' '3PT Running Jump Shot' 'Alley Oop Dunk'
#  'Driving Dunk' 'Driving Layup' 'Finger Roll' 'Putback Layup'
#  'Reverse Layup' 'Standard Dunk' 'Standard Layup' '2PT Floating Jump Shot'
#  'Driving Hook Shot' 'Alley Oop Layup' 'Hook Shot' 'Specialty Dunk'
#  'Turnaround Hook Shot' '3PT Step Back Jump Shot' 'Putback Dunk'
#  '2PT Running Jump Shot' '3PT Fadeaway Jump Shot'
#  '3PT Turnaround Jump Shot' 'Reverse Dunk' '3PT Floating Jump Shot']
#  3Pt Shots after mapping for player 2544: 0
# 2PT Field Goal    189
# 3PT Field Goal    106
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 106
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Floating Jump Shot' '2PT Jump Shot'
#  '2PT Pullup Jump Shot' '2PT Step Back Jump Shot'
#  '2PT Turnaround Jump Shot' '3PT Floating Jump Shot' '3PT Jump Shot'
#  '3PT Pullup Jump Shot' '3PT Running Jump Shot' '3PT Step Back Jump Shot'
#  'Alley Oop Dunk' 'Alley Oop Layup' 'Driving Dunk' 'Driving Layup'
#  'Finger Roll' 'Hook Shot' 'Putback Dunk' 'Putback Layup' 'Reverse Dunk'
#  'Reverse Layup' 'Specialty Dunk' 'Standard Dunk' 'Standard Layup'
#  '2PT Running Jump Shot' 'Driving Hook Shot' 'Turnaround Hook Shot'
#  '3PT Fadeaway Jump Shot' '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 106
# 2PT Field Goal    73
# 3PT Field Goal    26
# Name: SHOT_TYPE, dtype: int64
#  3Pt Shots before mapping for player 2544: 26
#
# Unique shot descriptions before mapping:
# ['2PT Fadeaway Jump Shot' '2PT Pullup Jump Shot' '3PT Jump Shot'
#  '3PT Pullup Jump Shot' '3PT Running Jump Shot' 'Finger Roll'
#  'Standard Layup' 'Alley Oop Dunk' '2PT Floating Jump Shot'
#  '2PT Jump Shot' '2PT Step Back Jump Shot' '2PT Turnaround Jump Shot'
#  'Alley Oop Layup' 'Driving Dunk' 'Driving Layup' 'Hook Shot'
#  'Putback Layup' 'Reverse Dunk' 'Reverse Layup' 'Specialty Dunk'
#  'Standard Dunk' '3PT Fadeaway Jump Shot' '3PT Step Back Jump Shot'
#  'Driving Hook Shot' 'Turnaround Hook Shot' '2PT Running Jump Shot'
#  'Putback Dunk' '3PT Floating Jump Shot' '3PT Turnaround Jump Shot']
#  3Pt Shots after mapping for player 2544: 26
#          shot_description  shot_count  shot_makes  year           shot_group
# 0           2PT Jump Shot       10818        3990  1997    TWO_POINT_JUMPERS
# 1   2PT Running Jump Shot         592         384  1997    TWO_POINT_JUMPERS
# 2           3PT Jump Shot        2684         904  1997  THREE_POINT_JUMPERS
# 3   3PT Running Jump Shot           2           2  1997  THREE_POINT_JUMPERS
# 4            Driving Dunk         110         108  1997                DUNKS
# ..                    ...         ...         ...   ...                  ...
# 24          Reverse Layup         142          82  2024               LAYUPS
# 25         Specialty Dunk         536         470  2024                DUNKS
# 26          Standard Dunk         450         412  2024                DUNKS
# 27         Standard Layup        1876        1110  2024               LAYUPS
# 28   Turnaround Hook Shot         304         168  2024           POST_MOVES
#
# [698 rows x 5 columns]

# %%
len(all_shots['shot_description'].unique())
# Out:
# 33

# %%
trail ='ps' if ps else ''
end_year= 2025 if ps else 2026
player_shots=pd.concat([pd.read_csv('shot_breakdown/'+str(year)+trail+'_shotbreakdown.csv') for year in range(1997,end_year)] )
player_shots.dropna(subset='shot_description',inplace=True)
player_shots

player_ids=player_shots['PLAYER_ID'].unique().tolist()


for player_id in player_ids:

    tempframe=player_shots[player_shots.PLAYER_ID==player_id]
    tempframe.to_csv('../extra_data/shot_averages/'+str(player_id)+'.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 trail ='ps' if ps else ''
#       2 end_year= 2026 if ps else 2025
# ----> 3 player_shots=pd.concat([pd.read_csv('shot_breakdown/'+str(year)+trail+'_shotbreakdown.csv') for year in range(1997,end_year)] )
#       4 player_shots.dropna(subset='shot_description',inplace=True)
#       5 player_shots
#
# Cell In[3], line 3, in <listcomp>(.0)
#       1 trail ='ps' if ps else ''
#       2 end_year= 2026 if ps else 2025
# ----> 3 player_shots=pd.concat([pd.read_csv('shot_breakdown/'+str(year)+trail+'_shotbreakdown.csv') for year in range(1997,end_year)] )
#       4 player_shots.dropna(subset='shot_description',inplace=True)
#       5 player_shots
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'shot_breakdown/2025ps_shotbreakdown.csv'
