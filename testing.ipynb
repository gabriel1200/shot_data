# %%
import pandas as pd
df = pd.read_csv('assists/2005/ast.csv')
df
# Out:
#        Unnamed: 0   GAME_ID  EVENTNUM  PLAYER_ID  ASSIST_ID     TEAM_ID  \
# 0             2.0  20400001         2       1888       1112  1610612765
# 1            18.0  20400001        18       1112       1888  1610612765
# 2            40.0  20400001        40       1497       1888  1610612765
# 3            66.0  20400001        67       1888       1497  1610612765
# 4           165.0  20400001       176       1112        283  1610612765
# ...           ...       ...       ...        ...        ...         ...
# 52337         NaN  20401230       300       2571       2405  1610612756
# 52338         NaN  20401230       411       2047       2207  1610612756
# 52339         NaN  20401230       420       2047        754  1610612756
# 52340         NaN  20401230       432       2571       2047  1610612756
# 52341         NaN  20401230       444        754       2321  1610612756
#
#            SHOT_ID
# 0        204000012
# 1       2040000118
# 2       2040000140
# 3       2040000167
# ...

# %%
len(df['GAME_ID'].unique())
# Out:
# 1230
