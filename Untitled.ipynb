# %%
import os
team_paths = os.listdir('team/2024')
files = [file for file in team_paths if file not in ['avg.csv','.ipynb_checkpoints']]
files
# Out:
# ['1610612737.csv',
#  '1610612737vs.csv',
#  '1610612738.csv',
#  '1610612738vs.csv',
#  '1610612739.csv',
#  '1610612739vs.csv',
#  '1610612740.csv',
#  '1610612740vs.csv',
#  '1610612741.csv',
#  '1610612741vs.csv',
#  '1610612742.csv',
#  '1610612742vs.csv',
#  '1610612743.csv',
#  '1610612743vs.csv',
#  '1610612744.csv',
#  '1610612744vs.csv',
#  '1610612745.csv',
#  '1610612745vs.csv',
#  '1610612746.csv',
#  '1610612746vs.csv',
#  '1610612747.csv',
#  '1610612747vs.csv',
#  '1610612748.csv',
#  '1610612748vs.csv',
#  '1610612749.csv',
#  '1610612749vs.csv',
#  '1610612750.csv',
#  '1610612750vs.csv',
#  '1610612751.csv',
#  '1610612751vs.csv',
#  '1610612752.csv',
#  '1610612752vs.csv',
#  '1610612753.csv',
#  '1610612753vs.csv',
#  '1610612754.csv',
#  '1610612754vs.csv',
#  '1610612755.csv',
#  '1610612755vs.csv',
#  '1610612756.csv',
#  '1610612756vs.csv',
#  '1610612757.csv',
#  '1610612757vs.csv',
#  '1610612758.csv',
#  '1610612758vs.csv',
#  '1610612759.csv',
# ...

# %%
# Out:
# team/.ipynb_checkpoints
# []
# team/1997
# ['.ipynb_checkpoints']
# team/1997ps
# []
# team/1998
# ['.ipynb_checkpoints']
# team/1998ps
# []
# team/1999
# []
# team/1999ps
# []
# team/2000
# []
# team/2000ps
# []
# team/2001
# []
# team/2001ps
# []
# team/2002
# []
# team/2002ps
# []
# team/2003
# ['.ipynb_checkpoints']
# team/2003ps
# []
# team/2004
# []
# team/2004ps
# []
# team/2005
# []
# team/2005ps
# ['.ipynb_checkpoints']
# team/2006
# []
# team/2006ps
# []
# team/2007
# []
# team/2007ps
# []
# team/2008
# []
# team/2008ps
# []
# team/2009
# []
# team/2009ps
# []
# team/2010
# []
# team/2010ps
# []
# team/2011
# []
# team/2011ps
# []
# team/2012
# []
# team/2012ps
# []
# team/2013
# []
# team/2013ps
# []
# team/2014
# []
# team/2014ps
# []
# team/2015
# []
# team/2015ps
# []
# team/2016
# []
# team/2016ps
# []
# team/2017
# []
# team/2017ps
# []
# team/2018
# []
# team/2018ps
# []
# team/2019
# []
# team/2019ps
# []
# team/2020
# []
# team/2020ps
# []
# team/2021
# []
# ...
